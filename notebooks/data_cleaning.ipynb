# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/Users/masoud/code/marcnaweb/car_recommendation_engine/raw_data/car_files_4c_en.csv')
df.head()
# Out:
# /var/folders/6w/hqgj441928d226x7jd74hkt00000gn/T/ipykernel_89090/4044910627.py:4: DtypeWarning: Columns (24,25,26,35,43,53,59,63,74,75,85,89,108,110,116,120,122,124,136,141,147,150,151,162,163,177,178,180,195,214,221,226,234,241,246,259,266,270,271,273,278,283,287,290) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/masoud/code/marcnaweb/car_recommendation_engine/raw_data/car_files_4c_en.csv')
#    Unnamed: 0.1  Unnamed: 0 Hot air Volumetric anti -first alarm  \
# 0             0         NaN     NaN                          NaN
# 1             1         NaN     NaN                          NaN
# 2             2         NaN     NaN                          NaN
# 3             3         NaN     NaN                          NaN
# 4             4         NaN     NaN                          NaN
#
#   Harman Kardon Sound System Track change alert Carbonaceramic brake disc  \
# 0                        NaN                NaN                       NaN
# 1                        NaN                NaN                       NaN
# 2                        NaN                NaN                       NaN
# 3                        NaN                NaN                       NaN
# 4                        NaN                NaN                       NaN
#
#   Arconditional Zones 2 Reclinarinar rear seat Maximum rotation  ...  \
# 0                   NaN                    NaN              NaN  ...
# 1                   NaN                    NaN              NaN  ...
# 2                   NaN                    NaN              NaN  ...
# 3                   NaN                    NaN              NaN  ...
# 4                   NaN                    NaN              NaN  ...
#
#   Folding rear seat Free wheel Shaker Pro Audio Sound System  \
# 0               NaN        NaN                           NaN
# 1               NaN        NaN                           NaN
# 2               NaN        NaN                           NaN
# 3               NaN        NaN                           NaN
# 4               NaN        NaN                           NaN
#
#   Maximum speed electric mode Electronic noise cancellation  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#   Steering wheel adjustment in depth Facial recognition camera Carcode  \
# 0                                NaN                       NaN       1
# 1                                NaN                       NaN       2
# 2                                NaN                       NaN       3
# 3                                NaN                       NaN       4
# 4                                NaN                       NaN       5
#
#   Perimeter anti theft alarm Track centralization assistant
# 0                        NaN                            NaN
# 1                        NaN                            NaN
# 2                        NaN                            NaN
# 3                        NaN                            NaN
# 4                        NaN                            NaN
#
# [5 rows x 291 columns]

# %% [markdown]
# ## Too many features with NaN's, remove columns which are more then 15000 Nan'n in column

# %%
filtered_columns = df.columns[df.isna().sum() < 15000]
filtered_df = df[filtered_columns]
filtered_df.head()
# Out:
#    Unnamed: 0.1 Hot air      Acceleration   Length Maximum torque  Assistance  \
# 0             0     NaN   0100 km/h 3,8 s  4580 mm      66,3 kgfm  Hydraulics
# 1             1     NaN  0100 km/h 15,2 s  3644 mm       8,5 kgfm  Unattended
# 2             2     NaN  0100 km/h 10,6 s  4177 mm      17,3 kgfm  Hydraulics
# 3             3     NaN               NaN      NaN            NaN         NaN
# 4             4     NaN   0100 km/h 8,5 s  4149 mm      21,4 kgfm  Hydraulics
#
#      Width Rev counter Compression ratio Assisted direction  ...  \
# 0  2045 mm         NaN             10,71                NaN  ...
# 1  1548 mm         NaN              9,51                NaN  ...
# 2  1709 mm         NaN              9,81                NaN  ...
# 3      NaN         NaN               NaN                NaN  ...
# 4  1735 mm         NaN              9,51                NaN  ...
#
#    USB connection Gear speed transmissions Corrected frontal area     Urban  \
# 0             NaN                      6.0              0,650 m^2  2,4 km/l
# 1             NaN                      5.0              0,684 m^2   10 km/l
# 2             NaN                      5.0              0,624 m^2  7,2 km/l
# 3             NaN                      NaN                    NaN       NaN
# 4             NaN                      5.0              0,651 m^2  6,8 km/l
#
#   Platform    Year Radio Folding rear seat Carcode  Perimeter anti theft alarm
# 0      NaN  2002.0   NaN               NaN       1                         NaN
# 1      NaN  2002.0   NaN               NaN       2                         NaN
# 2    Tbody  2002.0   NaN               NaN       3                         NaN
# 3      NaN     NaN   NaN               NaN       4                         NaN
# 4     PQ34  2002.0   NaN               NaN       5                         NaN
#
# [5 rows x 99 columns]

# %% [markdown]
# ## Drop some rows with a lot of Nan's

# %%
test_filtered_df =filtered_df.dropna(subset='Acceleration')
test_filtered_df
# Out:
#        Unnamed: 0.1             Hot air      Acceleration   Length  \
# 0                 0                 NaN   0100 km/h 3,8 s  4580 mm
# 1                 1                 NaN  0100 km/h 15,2 s  3644 mm
# 2                 2                 NaN  0100 km/h 10,6 s  4177 mm
# 4                 4                 NaN   0100 km/h 8,5 s  4149 mm
# 5                 5                 NaN   0100 km/h 9,5 s  4187 mm
# ...             ...                 ...               ...      ...
# 23881         23881  Standard equipment  0100 km/h 10,7 s  4015 mm
# 23882         23882  Standard equipment  0100 km/h 10,7 s  4015 mm
# 23890         23890  Standard equipment  0100 km/h 10,7 s  4015 mm
# 23902         23902  Standard equipment  0100 km/h 14,9 s  5413 mm
# 23903         23903  Standard equipment  0100 km/h 14,9 s  5998 mm
#
#       Maximum torque  Assistance    Width         Rev counter  \
# 0          66,3 kgfm  Hydraulics  2045 mm                 NaN
# 1           8,5 kgfm  Unattended  1548 mm                 NaN
# 2          17,3 kgfm  Hydraulics  1709 mm                 NaN
# 4          21,4 kgfm  Hydraulics  1735 mm                 NaN
# 5          16,7 kgfm  Hydraulics  1741 mm                 NaN
# ...              ...         ...      ...                 ...
# 23881    17,5 kgfm A  Electrical  1720 mm  Standard equipment
# 23882    17,5 kgfm A  Electrical  1720 mm  Standard equipment
# 23890    17,5 kgfm A  Electrical  1720 mm  Standard equipment
# 23902      34,7 kgfm  Hydraulics  2050 mm  Standard equipment
# 23903      34,7 kgfm  Hydraulics  2050 mm  Standard equipment
#
#       Compression ratio  Assisted direction  ...      USB connection  \
# 0                 10,71                 NaN  ...                 NaN
# 1                  9,51                 NaN  ...                 NaN
# 2                  9,81                 NaN  ...                 NaN
# 4                  9,51                 NaN  ...                 NaN
# 5                 10,31                 NaN  ...                 NaN
# ...                 ...                 ...  ...                 ...
# 23881             10,51  Standard equipment  ...  Standard equipment
# 23882             10,51  Standard equipment  ...  Standard equipment
# 23890             10,51  Standard equipment  ...  Standard equipment
# 23902               161  Standard equipment  ...  Standard equipment
# 23903               161  Standard equipment  ...  Standard equipment
#
#       Gear speed transmissions Corrected frontal area       Urban Platform  \
# 0                          6.0              0,650 m^2    2,4 km/l      NaN
# 1                          5.0              0,684 m^2     10 km/l      NaN
# 2                          5.0              0,624 m^2    7,2 km/l    Tbody
# 4                          5.0              0,651 m^2    6,8 km/l     PQ34
# 5                          5.0                    NaN      9 km/l      NaN
# ...                        ...                    ...         ...      ...
# 23881                      6.0                    NaN  8,3 km/l A       PB
# 23882                      6.0                    NaN  8,3 km/l A       PB
# 23890                      6.0                    NaN    9 km/l A       PB
# 23902                      6.0                    NaN     10 km/l      NaN
# 23903                      6.0                    NaN     10 km/l      NaN
#
#          Year               Radio   Folding rear seat Carcode  \
# 0      2002.0                 NaN                 NaN       1
# 1      2002.0                 NaN                 NaN       2
# 2      2002.0                 NaN                 NaN       3
# 4      2002.0                 NaN                 NaN       5
# 5      2002.0                 NaN                 NaN       6
# ...       ...                 ...                 ...     ...
# 23881  2024.0  Standard equipment  Standard equipment   23884
# 23882  2024.0  Standard equipment  Standard equipment   23885
# 23890  2024.0  Standard equipment  Standard equipment   23893
# 23902  2023.0  Optional equipment                 NaN   23905
# 23903  2023.0  Optional equipment                 NaN   23906
#
#        Perimeter anti theft alarm
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 4                             NaN
# 5                             NaN
# ...                           ...
# 23881          Standard equipment
# 23882          Standard equipment
# 23890          Standard equipment
# 23902          Optional equipment
# 23903          Optional equipment
#
# [20708 rows x 99 columns]

# %% [markdown]
# ## Check how much % is NaN in every column and check Dtype

# %%
nan_percentage_per_column = test_filtered_df.isnull().mean() * 100

# Create a new DataFrame with column names and NaN percentages and Dtypes
nan_info_df = pd.DataFrame({
    'Column Name': nan_percentage_per_column.index,
    'NaN Percentage': nan_percentage_per_column.values,
    'Data Type': test_filtered_df.dtypes
})

# Display the new DataFrame
nan_info_df[0:50] # Cheking 50 by 50 to see whole list at a time.
# Out:
#                                                              Column Name  \
# Unnamed: 0.1                                                Unnamed: 0.1
# Hot air                                                          Hot air
# Acceleration                                                Acceleration
# Length                                                            Length
# Maximum torque                                            Maximum torque
# Assistance                                                    Assistance
# Width                                                              Width
# Rev counter                                                  Rev counter
# Compression ratio                                      Compression ratio
# Assisted direction                                    Assisted direction
# CNW Ranking                                                  CNW Ranking
# ABS brakes                                                    ABS brakes
# Rear window                                                  Rear window
# Tuching                                                          Tuching
# Weight/Torque                                              Weight/Torque
# Guarantee                                                      Guarantee
# Drag coefficient                                        Drag coefficient
# Central locking of the doors                Central locking of the doors
# Height                                                            Height
# Valves per cylinder                                  Valves per cylinder
# Specific torque                                          Specific torque
# Aspiration                                                    Aspiration
# Minimum height from the ground            Minimum height from the ground
# Propulsion                                                    Propulsion
# Piston course                                              Piston course
# Rear tires                                                    Rear tires
# Urban autonomy                                            Urban autonomy
# Car gearbox                                                  Car gearbox
# Weight                                                            Weight
# Price R                                                          Price R
# Generation                                                    Generation
# Front suspension                                        Front suspension
# Coupling                                                        Coupling
# Headrest for all occupants                    Headrest for all occupants
# Front gauge                                                  Front gauge
# Spare tire                                                    Spare tire
# Fuel                                                                Fuel
# Electric rearview mirror adjustment  Electric rearview mirror adjustment
# Weight/power                                                Weight/power
# Rear suspension                                          Rear suspension
# Displacement                                                Displacement
# Valve command                                              Valve command
# Cooling liquid thermometer                    Cooling liquid thermometer
# Max power regime.                                      Max power regime.
# Places                                                            Places
# Turns diameter                                            Turns diameter
# Cylinder diameter                                      Cylinder diameter
# Disposition                                                  Disposition
# Cylinders                                                      Cylinders
# Elastic element                                          Elastic element
#
#                                      NaN Percentage Data Type
# Unnamed: 0.1                               0.000000     int64
# Hot air                                   46.233340    object
# Acceleration                               0.000000    object
# Length                                     0.000000    object
# Maximum torque                             0.709871    object
# Assistance                                 0.053120    object
# Width                                      0.000000    object
# Rev counter                               47.711030    object
# Compression ratio                          0.922349    object
# Assisted direction                        46.440989    object
# CNW Ranking                                0.000000   float64
# ABS brakes                                48.333977    object
# Rear window                               49.666795    object
# Tuching                                   42.080355    object
# Weight/Torque                              0.000000    object
# Guarantee                                  0.000000    object
# Drag coefficient                          37.328569    object
# Central locking of the doors              47.310218    object
# Height                                     0.000000    object
# Valves per cylinder                        0.714700   float64
# Specific torque                            0.709871    object
# Aspiration                                 0.709871    object
# Minimum height from the ground            45.484837    object
# Propulsion                                 0.000000    object
# Piston course                              1.028588    object
# Rear tires                                 0.000000    object
# Urban autonomy                             0.709871    object
# Car gearbox                                0.000000    object
# Weight                                     0.000000    object
# Price R                                    0.000000    object
# Generation                                31.243964    object
# Front suspension                           0.019316    object
# Coupling                                   0.767819    object
# Headrest for all occupants                56.412980    object
# Front gauge                               23.198764    object
# Spare tire                                51.178289    object
# Fuel                                       0.985127    object
# Electric rearview mirror adjustment       51.332818    object
# Weight/power                               0.000000    object
# Rear suspension                            0.019316    object
# Displacement                               0.709871    object
# Valve command                              0.777477    object
# Cooling liquid thermometer                55.934904    object
# Max power regime.                          0.709871    object
# Places                                     0.019316   float64
# Turns diameter                             0.053120    object
# Cylinder diameter                          1.028588    object
# Disposition                                0.709871    object
# Cylinders                                  0.714700    object
# Elastic element                            0.048291    object

# %% [markdown]
# ## After analysing all features, decided to remove some of them.
# Neither they don't give information, or they are hard to preprocess.

# %%
column_to_remove = ['Unnamed: 0.1','Assistance','Carcode','Aspiration', 'Rear tires', 'Spare tire', 'Front tires',
                    'Urban autonomy', 'Generation', 'Front suspension', 'Rear suspension', 'Coupling', 'Valve command',
                    'Places', 'Disposition', 'Cylinders', 'Elastic element', 'Ipva R', 'Frontal area A', 'Engine code',
                    'Traction', 'Installation', 'Road autonomy', 'Engine power supply', 'Engine control activation',
                    'Gear change code', 'Corrected frontal area', 'Platform']

# test_filtered_df['check feature name here'].unique() # check feature

# %%
new_filtered_df = test_filtered_df.drop(columns=column_to_remove)
new_filtered_df.head(3)
# Out:
#   Hot air      Acceleration   Length Maximum torque    Width Rev counter  \
# 0     NaN   0100 km/h 3,8 s  4580 mm      66,3 kgfm  2045 mm         NaN
# 1     NaN  0100 km/h 15,2 s  3644 mm       8,5 kgfm  1548 mm         NaN
# 2     NaN  0100 km/h 10,6 s  4177 mm      17,3 kgfm  1709 mm         NaN
#
#   Compression ratio Assisted direction  CNW Ranking ABS brakes  ...  \
# 0             10,71                NaN      20549.0        NaN  ...
# 1              9,51                NaN      14268.0        NaN  ...
# 2              9,81                NaN      12266.0        NaN  ...
#
#                Car size Unit displacement       Trunk USB connection  \
# 0                Grande          516 cm^3   50 litros            NaN
# 1  Compact and portable          250 cm^3  290 litros            NaN
# 2                Medium          500 cm^3  370 litros            NaN
#
#   Gear speed transmissions     Urban    Year  Radio Folding rear seat  \
# 0                      6.0  2,4 km/l  2002.0    NaN               NaN
# 1                      5.0   10 km/l  2002.0    NaN               NaN
# 2                      5.0  7,2 km/l  2002.0    NaN               NaN
#
#   Perimeter anti theft alarm
# 0                        NaN
# 1                        NaN
# 2                        NaN
#
# [3 rows x 71 columns]

# %% [markdown]
# # Preprocessing Features

# %% [markdown]
# ## Preprocessing All features with [Nan, standart equipment, optinal equipment]
# saved in: columns_to_transform ---------
# Nan = 0 ----------------
# standart equipment, optinal equipment = 1

# %%
preprocessing_df = new_filtered_df.copy()

columns_to_transform = ['Hot air', 'Rev counter', 'Assisted direction', 'ABS brakes', 'Rear window', 'Central locking of the doors',
                        'Headrest for all occupants', 'Electric rearview mirror adjustment', 'Air conditioning',
                        'Bluetooth connection', 'Frontal Airbags', 'Steering wheel adjustment height',
                        'Electric front window control', 'Multifunctional steering wheel', 'Driver s seat with height adjustment',
                        'On board computer', 'Light in the trunk', 'Alloy wheels', 'USB connection', 'Radio',
                        'Folding rear seat', 'Perimeter anti theft alarm', 'Cooling liquid thermometer']

# Replace NaN with 0 and other values with 1
preprocessing_df[columns_to_transform] = preprocessing_df[columns_to_transform].applymap(lambda x: 0 if pd.isnull(x) else 1)
# Out:
# /var/folders/6w/hqgj441928d226x7jd74hkt00000gn/T/ipykernel_89090/589099134.py:11: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   preprocessing_df[columns_to_transform] = preprocessing_df[columns_to_transform].applymap(lambda x: 0 if pd.isnull(x) else 1)

# %% [markdown]
# ## Preprocessing [Acceleration]

# %%
# Preprocess Acceleration (0100 km/h 3,8 s = 3.8)
preprocessing_df['Acceleration'] = preprocessing_df['Acceleration'].str.extract(r'(\d+\,\d+)')

# Replace ',' with '.' and convert to numeric
preprocessing_df['Acceleration'] = preprocessing_df['Acceleration'].str.replace(',', '.').astype(float)
# Rename Column
preprocessing_df = preprocessing_df.rename(columns={'Acceleration': 'Acceleration 0100 km/h in S'})

# %%
preprocessing_df['Cooling liquid thermometer'].unique()
# Out:
# array([0, 1])

# %%
# filtered_df.to_csv("df_main_features.csv")

# %%
preprocessing_df
# Out:
#        Hot air  Acceleration 0100 km/h in S   Length Maximum torque    Width  \
# 0            0                          3.8  4580 mm      66,3 kgfm  2045 mm
# 1            0                         15.2  3644 mm       8,5 kgfm  1548 mm
# 2            0                         10.6  4177 mm      17,3 kgfm  1709 mm
# 4            0                          8.5  4149 mm      21,4 kgfm  1735 mm
# 5            0                          9.5  4187 mm      16,7 kgfm  1741 mm
# ...        ...                          ...      ...            ...      ...
# 23881        1                         10.7  4015 mm    17,5 kgfm A  1720 mm
# 23882        1                         10.7  4015 mm    17,5 kgfm A  1720 mm
# 23890        1                         10.7  4015 mm    17,5 kgfm A  1720 mm
# 23902        1                         14.9  5413 mm      34,7 kgfm  2050 mm
# 23903        1                         14.9  5998 mm      34,7 kgfm  2050 mm
#
#        Rev counter Compression ratio  Assisted direction  CNW Ranking  \
# 0                0             10,71                   0      20549.0
# 1                0              9,51                   0      14268.0
# 2                0              9,81                   0      12266.0
# 4                0              9,51                   0      16041.0
# 5                0             10,31                   0       9142.0
# ...            ...               ...                 ...          ...
# 23881            1             10,51                   1         63.0
# 23882            1             10,51                   1         54.0
# 23890            1             10,51                   1         50.0
# 23902            1               161                   1       1073.0
# 23903            1               161                   1       1068.0
#
#        ABS brakes  ...              Car size Unit displacement         Trunk  \
# 0               0  ...                Grande          516 cm^3     50 litros
# 1               0  ...  Compact and portable          250 cm^3    290 litros
# 2               0  ...                Medium          500 cm^3    370 litros
# 4               0  ...                Medium          445 cm^3    330 litros
# 5               0  ...                Medium          437 cm^3    370 litros
# ...           ...  ...                   ...               ...           ...
# 23881           1  ...  Compact and portable          333 cm^3    300 litros
# 23882           1  ...  Compact and portable          333 cm^3    300 litros
# 23890           1  ...  Compact and portable          333 cm^3    300 litros
# 23902           1  ...                Grande          545 cm^3  11500 litros
# 23903           1  ...                Grande          545 cm^3  13000 litros
#
#       USB connection Gear speed transmissions       Urban    Year  Radio  \
# 0                  0                      6.0    2,4 km/l  2002.0      0
# 1                  0                      5.0     10 km/l  2002.0      0
# 2                  0                      5.0    7,2 km/l  2002.0      0
# 4                  0                      5.0    6,8 km/l  2002.0      0
# 5                  0                      5.0      9 km/l  2002.0      0
# ...              ...                      ...         ...     ...    ...
# 23881              1                      6.0  8,3 km/l A  2024.0      1
# 23882              1                      6.0  8,3 km/l A  2024.0      1
# 23890              1                      6.0    9 km/l A  2024.0      1
# 23902              1                      6.0     10 km/l  2023.0      1
# 23903              1                      6.0     10 km/l  2023.0      1
#
#       Folding rear seat Perimeter anti theft alarm
# 0                     0                          0
# 1                     0                          0
# 2                     0                          0
# 4                     0                          0
# 5                     0                          0
# ...                 ...                        ...
# 23881                 1                          1
# 23882                 1                          1
# 23890                 1                          1
# 23902                 0                          1
# 23903                 0                          1
#
# [20708 rows x 71 columns]

# %%
# Mahdi Data Cleaning

# %%
# Clean 'Car payload'
preprocessing_df['Car payload'] = preprocessing_df['Car payload'].str.replace(' kg', '', regex=True).astype('Int64')

# Clean 'Specific power'
preprocessing_df['Specific power'] = preprocessing_df['Specific power'].str.replace(' cv/litro', '', regex=True)
preprocessing_df['Specific power'] = preprocessing_df['Specific power'].str.replace(',', '.', regex=True).astype(float)

# Clean 'CNW Index'
# preprocessing_df['CNW Index'] = preprocessing_df['CNW Index'].str.replace(',', '.', regex=True)

# Clean 'Reader score'
preprocessing_df['Reader score'] = preprocessing_df['Reader score'].str.replace(',', '.', regex=True).astype(float)

# Clean 'Sidewall height'
preprocessing_df['Sidewall height'] = preprocessing_df['Sidewall height'].str.replace(' mm', '', regex=True).astype(float)

# Clean 'Provenance' (removing special characters and leading/trailing spaces)
preprocessing_df['Provenance'] = preprocessing_df['Provenance'].str.replace('[^a-zA-Z0-9\s]', '', regex=True)
preprocessing_df['Provenance'] = preprocessing_df['Provenance'].str.strip()

# Clean 'Doors'
preprocessing_df['Doors'] = preprocessing_df['Doors'].astype('Int64')

# Clean 'Maximum power'
preprocessing_df['Maximum power'] = preprocessing_df['Maximum power'].str.replace('[^0-9.]', '', regex=True).astype(float)

# Clean 'Settings'
preprocessing_df['Settings'] = preprocessing_df['Settings'].str.replace('[^a-zA-Z0-9\s]', '', regex=True)
preprocessing_df['Settings'] = preprocessing_df['Settings'].str.strip()

# Clean 'Car size'
preprocessing_df['Car size'] = preprocessing_df['Car size'].str.replace('[^a-zA-Z0-9\s]', '', regex=True)
preprocessing_df['Car size'] = preprocessing_df['Car size'].str.strip()

# Clean 'Unit displacement'
preprocessing_df['Unit displacement'] = preprocessing_df['Unit displacement'].str.replace('[^0-9.]', '', regex=True).astype(float)

# Clean 'Trunk'
preprocessing_df['Trunk'] = preprocessing_df['Trunk'].str.replace('[a-zA-Z\s]', '', regex=True).astype(float)

# Clean 'Urban'
preprocessing_df['Urban'] = preprocessing_df['Urban'].str.replace(',', '.', regex=True)
preprocessing_df['Urban'] = preprocessing_df['Urban'].str.replace('[^0-9.]', '', regex=True).astype(float)

# Clean 'Year'
preprocessing_df['Year'] = preprocessing_df['Year'].astype('Int64')
