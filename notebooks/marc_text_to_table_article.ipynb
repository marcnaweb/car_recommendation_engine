# %% [markdown]
# # Introduction

# %% [markdown]
# In this article, we will present how we can handle semi-structured documents using TFID, a Natural Language Processing technique to create a table containing all the information we are looking to analyze.
#
# The challenge with semi-structured data is that we don't know, in advance, the data structure we are looking for, after all, labels can change over time and depend on the product being described.
#
# Think about an Invoice, a Technical Specifications or a Bill of Materials for instance: although we know that we will find a series of labels (or descriptors) and their respective values, we don't know, in advance, what labels we will find within all the documents we might receive, since each one is describing a different product (or item).
#
# To make things worse, this is an expected situation of any semi-structured data: after all, we don't know what may come in the future: why should technical specifications of an old car specify if there is a USB connector in the car if there was obviously no USB ten years ago?
#
# Also, why should a bill of material specify the colour of a tissue if it describes the materials needed to make a table (that doesn't use any tissue)?
#
# Still, we may need to find all the tissue consumed by a furniture factory, that might be producing not only tables but sofas too!
#
# This makes the traditional way of defining "labels" and extracting their corresponding values completely useless, or at least not scalable in the long run.
#
# Still, let's accept this challenge and see how we can solve it: TFIDF here we go!

# %% [markdown]
# # General Strategy

# %% [markdown]
# Here we will be extracting information about the technical specifications of cars: to create a big table containing all the features a car might have, we will look at their technical specifications in order to:
# 1/Find what features should be included in the table columns and
# 2/Fullfill the columns with the specifications for each car.
#
# For this analysis we will use a "Term Frequency - Inverse Document Frequency" (TF-IDF) technique to weigh each word of the car's specification: this will allow us to define a threshold and easily identify "labels" and "values": where label words have lower values and "value words" have, well, higher values.
#
# Although TD-IDF has diverse implications and a complex definition that we will not cover in this article (but it can be saw here) its concept is relatively easy to grasp: it basically weights common words with lower values (in our cases, words that are present in Labels) and rare words with higher values (in our cases, values presented in the technical specifications): just what we need to extract the label-values pair from our car technical specifications!
#
# As a final step, we will clean the labels found during a first round to make sure they are part of our common language, after all, we don't want labels to include jargon words, making sure that the information is understandable by all stakeholders.

# %% [markdown]
# # Technical setp-up

# %% [markdown]
# To handle our challenge, we will use a large set of Python libraries: not only our friends Pandas and Numpy but also re (for regex modifications) stopwords and other libraries that will help to solve our journey, so here is our initial set-up.

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
import string
import re
import os
from nltk.corpus import stopwords
import math
import random
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import Counter

# %% [markdown]
# # First Round: estimating label candidates

# %% [markdown]
# Here is a escrapt of our data (in English for the sake of clarity): composed of more than 20 thousant files of technical specifications of cars (!) each line present some feature and its respective value: keep in mind not all values are numbers (E.g. car origin or fuel) nor are all labels in front of values (check the car cylinders for instance):
#
# <code>
#
# <br/>
# Year 2003 <br/>
# Price R$ 30,303<br/>
# Combustion Propulsion<br/>
# Gasoline Fuel<br/>
# National Origin<br/>
# Warranty 1 year <br/>
# Jeep Configuration<br/>
# Compact Size<br/>
# Places 5<br/>
# 4 doors<br/>
# Motor<br/>
# Front Installation<br/>
# Longitudinal Layout<br/>
# Vacuuming Natural<br/>
# Power Multipoint injection<br/>
# 3 cylinders in line<br/>
# Single valve control in the cylinder head<br/>
# Valves per cylinder 4<br/>
# Cylinder diameter 81.5 mm<br/>
# Piston stroke 95.8 mm<br/>
# Compression ratio 9.5:1<br/>
# Equipment<br/>
# Standard equipment ABS brakes<br/>
# Standard equipment Front airbags<br/>
# Standard equipment Side airbags<br/>
# Standard equipment Perimeter anti-theft alarm<br/>
# Standard equipment Rear camera for maneuvering<br/>
# Standard equipment 3-point seat belts for all occupants<br/>
# Standard equipment Headrest for all occupants<br/>
# Radio series equipment<br/>
# CD player standard equipment<br/>
# Standard equipment Front airbags<br/>
# Optional equipment Perimeter anti-theft alarm<br/>
# Optional equipment Volumetric anti-theft alarm<br/>
# Standard equipment Headrest for all occupants<br/>
# Optional equipment Fog lights<br/>
# Standard equipment Rear window wiper and washer<br/>
# Optional equipment Rear fog light<br/>
# Optional equipment Side turn signal repeaters<br/>
# Optional equipment Central door locking
# </code>

# %% [markdown]
# Ok, let's go ahead and extract some sample files

# %%
# Set the file path
file_path = "path/to/the/folder/"

files = os.listdir(file_path)
random.shuffle(files) # shuffle the files to get a random sample
text_files = files[1000:1030]  # get a sample of 30 files
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 # Set the file path
#       2 file_path = "path/to/the/folder/"
# ----> 4 files = os.listdir(file_path)
#       5 random.shuffle(files) # shuffle the files to get a random sample
#       6 text_files = files[1000:1030]  # get a sample of 30 files
#
# FileNotFoundError: [Errno 2] No such file or directory: 'path/to/the/folder/'

# %%
text_files  = ['22397.txt',
 '16273.txt',
 '13249.txt',
 '21550.txt',
 '22013.txt',
 '23487.txt',
 '14521.txt',
 '14910.txt',
 '934.txt',
 '14426.txt',
 '22821.txt',
 '9066.txt',
 '2087.txt',
 '5011.txt',
 '1667.txt',
 '6068.txt',
 '3122.txt',
 '19168.txt',
 '21872.txt',
 '11505.txt',
 '14847.txt',
 '12923.txt',
 '22962.txt',
 '15261.txt',
 '1185.txt',
 '3034.txt',
 '2039.txt',
 '4564.txt',
 '5563.txt',
 '15147.txt']

file_path = '/home/marcnaweb/code/marcnaweb/car_recommendation_engine/raw_data/text_files/extracted_datasheets/'

# %% [markdown]
# Since our content are have values for each line, let's open our files and create our content in a "per line" based

# %%
text_content = []

for file in text_files:
    with open(f"{file_path}{file}", 'r') as file:
        content = file.read()
        try:

            content = content.split('\n') # split the content by lines --> each line is (very small) document
        except:
            pass
    temp = []
    for line in content:
        #doing some basic cleaning
        #pass
        # Remove words in between brackets
        line = re.sub(r'\[.*?\]', ' ', line)

        words = line.split()
        # Remove words that contain a special character
        words = [word for word in words if all(  c == '\n' or c == '/'  or c =='.' or c == ',' for c in string.punctuation if c in word)]

        #include a position indicator to the words that are not stopwords
        # from left to right
        words = [f"{i}_{word}" if word not in stopwords.words('portuguese') else word for i, word in enumerate(words)]
        # from right to left
        words.reverse()
        words = [f"{i}_{word}" if word not in stopwords.words('portuguese') else word for i, word in enumerate(words)]
        #reput the words in the right order
        words.reverse()

        cleaned_line = ' '.join(words)
        #print(cleaned_line)
        text_content.append(cleaned_line)

#print(text_content)

# %% [markdown]
# Yes, you spot it: we are not only cleaning a bit our data but also enriching our words with a position indicator: from right to left and left to righ, why?
# Remember that we spot that labels (and values) might be in the beginning or in the end end of each line: e.g. in "Year 2003" and "Warrenty 1 year" the word "year" might have a different value (or meaning) depending or its position in the sentence, and if we don't include this indicator, our TD-IDF matrix will give the same value for it and may completely ruin our results: after all, in "Year 2003" the _label_ is year while in "Warrenty 1 year" the _value_ is year, isn't it?

# %% [markdown]
# It's show time: get ready for your engine to run (and your computer to heat! ;)
# Heredown we make our matrix of weighted words and respective sentence, as we will see this is essential for continuing with our analisys.

# %%
corpus = text_content
vectorizer = TfidfVectorizer(min_df=1 , stop_words=stopwords.words('portuguese') , token_pattern=r'\b[\w_,.]*[_,.][\w_,.]*\b' )  #
X = vectorizer.fit(corpus)
vectorizer.transform(corpus).toarray()
vectorizer.get_feature_names_out()

weighted_words = pd.DataFrame(vectorizer.fit_transform(corpus).toarray(),
                 columns = vectorizer.get_feature_names_out(), index = corpus)

weighted_words.reset_index(inplace=True)
weighted_words["temp"] = weighted_words["index"].apply(lambda x: len(x.split()))
weighted_words =    weighted_words[weighted_words["temp"] > 0 ].drop(columns=["temp"])
weighted_words.reset_index(inplace=True)
weighted_words.drop(columns=["level_0"], inplace=True)

# %% [markdown]
# Now let's stop for a while and see what we have here, how are our weighted words behaving in the different lines?

# %%
line_number = 28917
line = weighted_words[weighted_words.index == line_number ]['index'].values[0]
line_weight = weighted_words[weighted_words.index == line_number].select_dtypes(include=[np.number]).T.sort_values(line_number, ascending=False)

print(line)
line_weight[line_weight[line_number] > 0]
# Out:
# 3_0_Velocidade 2_1_máxima 1_2_158 0_3_km/h
#                    28917
# 1_2_158         0.612644
# 0_3_km          0.472319
# 3_0_velocidade  0.472319
# 2_1_máxima      0.422489

# %% [markdown]
# So let's stop and see what we have.
# - the original input was: "Velocidade máxima 158 km/h"  (meaning: Maximum Speed 158 km/h)
# - after the initial transformation we have: "3_0_Velocidade 2_1_máxima 1_2_158 0_3_km/h"
# And the weighted words are propery indicating a ghigher value for 158, than the "km" "velocidade" and speed. Yey, we have our value: just take the higher value right?
#
# Not so fast: what if we have a composed word as a value?

# %%
line_number = 28489
line = weighted_words[weighted_words.index == line_number ]['index'].values[0]
line_weight = weighted_words[weighted_words.index == line_number].select_dtypes(include=[np.number]).T.sort_values(line_number, ascending=False)

print(line)
line_weight[line_weight[line_number] > 0]
# Out:
# 5_0_Equipamento de 3_2_série 2_3_Banco 1_4_traseiro 0_5_rebatível
#                     28489
# 0_5_rebatível    0.504686
# 2_3_banco        0.480824
# 1_4_traseiro     0.480824
# 3_2_série        0.379142
# 5_0_equipamento  0.373042

# %% [markdown]
# Here, we have:
# - the original imput as: "Equipamento de série Banco traseiro rebatível" (meaning: "Standard equipment Folding rear seat" )
# - after the initial transformation: "5_0_Equipamento de 3_2_série 2_3_Banco 1_4_traseiro 0_5_rebatíve"
# - and the higher value is "rebatível" meaning "foldin"
#
# but what about "rear" "seat", they too deserve to be a value!
#
# It's clear here that we need a threshold, so let's check further this case..

# %%
line_weight[line_weight[line_number] > 0].describe()
# Out:
#           28489
# count  5.000000
# mean   0.443704
# std    0.062522
# min    0.373042
# 25%    0.379142
# 50%    0.480824
# 75%    0.480824
# max    0.504686

# %% [markdown]
# Ok, the mean seems a good threshold to filter the words: let's check with other cases.

# %%
line_number = 28410
line = weighted_words[weighted_words.index == line_number ]['index'].values[0]
line_weight = weighted_words[weighted_words.index == line_number].select_dtypes(include=[np.number]).T.sort_values(line_number, ascending=False)

print(line)
print(line_weight[line_weight[line_number] > 0])
line_weight[line_weight[line_number] > 0].describe()
# Out:
# 4_0_Regime 3_1_potência 2_2_máx. 1_3_6000 0_4_rpm
#                  28410
# 1_3_6000      0.542390
# 3_1_potência  0.446697
# 4_0_regime    0.410802
# 2_2_máx       0.410802
# 0_4_rpm       0.410802
#           28410
# count  5.000000
# mean   0.444299
# std    0.056995
# min    0.410802
# 25%    0.410802
# 50%    0.410802
# 75%    0.446697
# max    0.542390

# %% [markdown]
# here we have:
# - as the original text input: "Regime potência máx. 6000 rpm" (meaning: Max regime power. 6,000rpm )
# - after transformation: 4_0_Regime 3_1_potência 2_2_máx. 1_3_6000 0_4_rpm
# and with the words abose the mean value: "potência" and "6000", not quite what we are looking for,, but closer, indeed.
#
# So,, after a while of trial and error (and yes, RNNs could help here) I realized that the follwoing calculation is a good threshold:
#
# threshold  = mean + standard deviation / count
#
# But no, I don't know why it works neither,, sorry guys..

# %% [markdown]
# Let's implement it programmatically

# %%
cutting_value = line_weight[line_weight[line_number] > 0].describe().loc['mean'] + line_weight[line_weight[line_number] > 0].describe().loc['std'] / line_weight[line_weight[line_number] > 0].describe().loc['count']
cutting_value = cutting_value.values[0]
cutting_value
# Out:
# 0.45569763962547083

# %% [markdown]
# And now for all our files..

# %%
def get_top_words(line_weight, cutting_value):
    print(cutting_value)
    top_words = line_weight[line_weight[line_number] > cutting_value]
    #print(top_words.index.tolist())
    value_to_return = top_words.index.tolist()
    value_to_return.reverse()
    return value_to_return

# %%
def get_label_and_value(line, value_words):
    words = value_words
    pattern = r'({}[^\s]*).*?'.format('|'.join(words)) * len(words)

    # Find the string between the words
    match = re.search(pattern, line, re.DOTALL)
    #match = re.findall(pattern, line, re.DOTALL)

    print(match)


    if match:
        # get the value words
        result = match.group()
        #clean the string from position indicators _0, _1, _2, etc
        pattern = r'\b\w*_'
        result = re.sub(pattern, '', result)
        print(f"found value: {result}")

        #remove the result from line to get the label
        line = re.sub(pattern, '', line)
        label = line.replace(result, '')
        label = label.replace('  ', ' ') # remove double spaces

        #clean the string from position indicators _0, _1, _2, etc
        pattern = r'\b\w*_'
        label = re.sub(pattern, '', label)
        print("found label: " + label)



        return label, result

    else:
        print('No match found')

# %%
label_values_list = []

for line_number in weighted_words.index.tolist():
    print(f"line_number: {line_number}")

    line = weighted_words[weighted_words.index == line_number]['index'].values[0]

    if len(line.split()) > 1:
        print(line)

        #get line weight
        line_weight = weighted_words[weighted_words.index == line_number].select_dtypes(include=[np.number]).T.sort_values(line_number, ascending=False)

        #get cutting value =  mean + (standard deviation) divided by (count)
        cutting_value = line_weight[line_weight[line_number] > 0].describe().loc['mean'] + line_weight[line_weight[line_number] > 0].describe().loc['std'] / line_weight[line_weight[line_number] > 0].describe().loc['count']
# found value: equipamento de série
# found label:
# line_number: 28831
# 3_0_Equipamento 2_1_opcional 1_2_Equipamento 0_3_opcional
# 0.5086321755855967
# <re.Match object; span=(29, 57), match='1_2_equipamento 0_3_opcional'>
# found value: equipamento opcional
# found label:
# line_number: 28832
# 6_0_Chevrolet 5_1_S10 4_2_De 3_3_Luxe 2_4_2.5 1_5_Turbo 0_6_CS
# 0.3789990077877763
# <re.Match object; span=(22, 55), match='4_2_de 3_3_luxe 2_4_2.5 1_5_turbo'>
# found value: de luxe 2.5 turbo
# found label: chevrolet s10 cs
# line_number: 28833
# 1_0_Ano 0_1_1998
# 0.7577719659502062
# <re.Match object; span=(8, 16), match='0_1_1998'>
# found value: 1998
# found label: ano
# line_number: 28834
# 1_0_Preço 0_1_33.129
# 0.7653997821124626
# <re.Match object; span=(10, 20), match='0_1_33.129'>
# found value: 33.129
# found label: preço
# line_number: 28835
# line_number: 28836
# 1_0_Propulsão 0_1_Combustão
# 0.7071067811865476
# <re.Match object; span=(0, 0), match=''>
# found value:
# found label: propulsão combustão
# line_number: 28837
# 1_0_Combustível 0_1_Diesel
# 0.7431990646784468
# <re.Match object; span=(16, 26), match='0_1_diesel'>
# found value: diesel
# found label: combustível
# line_number: 28838
# line_number: 28839
# 1_0_Procedência 0_1_Nacional
# 0.7170597224566053
# <re.Match object; span=(16, 28), match='0_1_nacional'>
# found value: nacional
# found label: procedência
# line_number: 28840
# 2_0_Garantia 1_1_1 0_2_ano
# 0.5824253785482817
# <re.Match object; span=(13, 26), match='1_1_1 0_2_ano'>
# found value: 1 ano
# found label: garantia
# line_number: 28841
# 1_0_Configuração 0_1_Picape
# 0.7396706379529274
# <re.Match object; span=(17, 27), match='0_1_picape'>
# found value: picape
# found label: configuração
# line_number: 28842
# 1_0_Porte 0_1_Médio
# 0.7223627888637312
# <re.Match object; span=(10, 19), match='0_1_médio'>
# found value: médio
# found label: porte
# line_number: 28843
# 1_0_Lugares 0_1_3
# 0.7431990646784468
# <re.Match object; span=(12, 17), match='0_1_3'>
# found value: 3
# found label: lugares
# line_number: 28844
# 1_0_Portas 0_1_2
# 0.7243321570090652
# <re.Match object; span=(11, 16), match='0_1_2'>
# found value: 2
# found label: portas
# line_number: 28845
# 1_0_Geração 0_1_1
# 0.7356476004621686
# <re.Match object; span=(12, 17), match='0_1_1'>
# found value: 1
# found label: geração
# line_number: 28846
# 2_0_Índice 1_1_CNW 0_2_22,42
# 0.6061287475907359
# <re.Match object; span=(19, 28), match='0_2_22,42'>
# found value: 22,42
# found label: índice cnw
# line_number: 28847
# 2_0_Ranking 1_1_CNW 0_2_19227
# 0.6061287475907359
# <re.Match object; span=(20, 29), match='0_2_19227'>
# found value: 19227
# found label: ranking cnw
# line_number: 28848
# 3_0_Nota do 1_2_Leitor 0_3_8,5
# 0.591657776456864
# <re.Match object; span=(23, 30), match='0_3_8,5'>
# found value: 8,5
# found label: nota do leitor
# line_number: 28849
# line_number: 28850
# 1_0_Instalação 0_1_Dianteiro
# 0.7071067811865476
# <re.Match object; span=(0, 0), match=''>
# found value:
# found label: instalação dianteiro
# line_number: 28851
# 1_0_Disposição 0_1_Longitudinal
# 0.7286637975117709
# <re.Match object; span=(15, 31), match='0_1_longitudinal'>
# found value: longitudinal
# found label: disposição
# line_number: 28852
# 1_0_Aspiração 0_1_Turbocompressor
# 0.7310698421252375
# <re.Match object; span=(14, 33), match='0_1_turbocompressor'>
# found value: turbocompressor
# found label: aspiração
# line_number: 28853
# 2_0_Alimentação 1_1_Injeção 0_2_direta
# 0.5881522179677215
# <re.Match object; span=(28, 38), match='0_2_direta'>
# found value: direta
# found label: alimentação injeção
# line_number: 28854
# 3_0_Cilindros 2_1_4 em 0_3_linha
# 0.5794038066129341
# <re.Match object; span=(14, 19), match='2_1_4'>
# found value: 4
# found label: cilindros em linha
# line_number: 28855
# 5_0_Comando de 3_2_válvulas 2_3_Único no 0_5_cabeçote
# 0.5036852941297785
# <re.Match object; span=(28, 37), match='2_3_único'>
# found value: único
# found label: comando de válvulas no cabeçote
# line_number: 28856
# 4_0_Acionam. do 2_2_comando 1_3_Correia 0_4_dentada
# 0.5
# <re.Match object; span=(0, 0), match=''>
# found value:
# found label: acionam. do comando correia dentada
# line_number: 28857
# 1_0_Tuchos 0_1_Mecânicos
# 0.7341492129779218
# <re.Match object; span=(11, 24), match='0_1_mecânicos'>
# found value: mecânicos
# found label: tuchos
# line_number: 28858
# 3_0_Válvulas por 1_2_cilindro 0_3_2
# 0.586868426136804
# <re.Match object; span=(30, 35), match='0_3_2'>
# found value: 2
# found label: válvulas por cilindro
# line_number: 28859
# 4_0_Diâmetro do 2_2_cilindro 1_3_90,74 0_4_mm
# 0.5172172136767237
# <re.Match object; span=(29, 38), match='1_3_90,74'>
# found value: 90,74
# found label: diâmetro do cilindro mm
# line_number: 28860
# 4_0_Curso do 2_2_pistão 1_3_97 0_4_mm
# 0.5165974782990196
# <re.Match object; span=(24, 30), match='1_3_97'>
# found value: 97
# found label: curso do pistão mm
# line_number: 28861
# 2_0_Razão de 0_2_compressão
# 0.7071067811865476
# <re.Match object; span=(0, 0), match=''>
# found value:
# found label: razão de compressão
# line_number: 28862
# 4_0_Código do 2_2_motor 1_3_Maxion 0_4_HS
# 0.5048440623611725
# <re.Match object; span=(24, 41), match='1_3_maxion 0_4_hs'>
# found value: maxion hs
# found label: código do motor
# line_number: 28863
# 2_0_Cilindrada 1_1_unitária 0_2_627
# 0.6025141321948855
# <re.Match object; span=(28, 35), match='0_2_627'>
# found value: 627
# found label: cilindrada unitária
# line_number: 28864
# 1_0_Deslocamento 0_1_2509
# 0.7653997821124626
# <re.Match object; span=(17, 25), match='0_1_2509'>
# found value: 2509
# found label: deslocamento
# line_number: 28865
# 3_0_Potência 2_1_máxima 1_2_95 0_3_cv
# 0.5168929076917436
# <re.Match object; span=(24, 30), match='1_2_95'>
# found value: 95
# found label: potência máxima cv
# line_number: 28866
# 4_0_Regime 3_1_potência 2_2_máx. 1_3_3800 0_4_rpm
# 0.4569239136864605
# <re.Match object; span=(33, 41), match='1_3_3800'>
# found value: 3800
# found label: regime potência máx. rpm
# line_number: 28867
# 3_0_Torque 2_1_máximo 1_2_22,4 0_3_kgfm
# 0.5158943857770186
# <re.Match object; span=(22, 30), match='1_2_22,4'>
# found value: 22,4
# found label: torque máximo kgfm
# line_number: 28868
# 4_0_Regime 3_1_torque 2_2_máx. 1_3_1800 0_4_rpm
# 0.45569763962547083
# <re.Match object; span=(31, 39), match='1_3_1800'>
# found value: 1800
# found label: regime torque máx. rpm
# line_number: 28869
# 2_0_Peso/potência 1_1_18,26 0_2_kg/cv
# 0.6120983463126416
# <re.Match object; span=(18, 27), match='1_1_18,26'>
# found value: 18,26
# found label: peso/potência kg/cv
# line_number: 28870
# 3_0_Torque 2_1_específico 1_2_8,9 0_3_kgfm/litro
# 0.5145889243879291
# <re.Match object; span=(26, 33), match='1_2_8,9'>
# found value: 8,9
# found label: torque específico kgfm/litro
# line_number: 28871
# 2_0_Peso/torque 1_1_77,5 0_2_kg/kgfm
# 0.6120983463126416
# <re.Match object; span=(16, 24), match='1_1_77,5'>
# found value: 77,5
# found label: peso/torque kg/kgfm
# line_number: 28872
# 3_0_Potência 2_1_específica 1_2_37,9 0_3_cv/litro
# 0.5158943857770186
# <re.Match object; span=(28, 36), match='1_2_37,9'>
# found value: 37,9
# found label: potência específica cv/litro
# line_number: 28873
# 3_0_Rotação 2_1_máxima 1_2_4640 0_3_rpm
# 0.5144390462265949
# <re.Match object; span=(23, 31), match='1_2_4640'>
# found value: 4640
# found label: rotação máxima rpm
# line_number: 28874
# line_number: 28875
# 1_0_Tração 0_1_Traseira
# 0.7586440521412725
# <re.Match object; span=(11, 23), match='0_1_traseira'>
# found value: traseira
# found label: tração
# line_number: 28876
# 1_0_Câmbio 0_1_Manual
# 0.7205023840237847
# <re.Match object; span=(11, 21), match='0_1_manual'>
# found value: manual
# found label: câmbio
# line_number: 28877
# 1_0_Marchas 0_1_5
# 0.7188038422059329
# <re.Match object; span=(0, 11), match='1_0_marchas'>
# found value: marchas
# found label:  5
# line_number: 28878
# 4_0_Acoplamento 3_1_Embreagem 2_2_monodisco a 0_4_seco
# 0.5
# <re.Match object; span=(0, 0), match=''>
# found value:
# found label: acoplamento embreagem monodisco a seco
# line_number: 28879
# line_number: 28880
# 3_0_Dianteira 2_1_Indep., 1_2_braços 0_3_sobrepostos
# 0.5008635825210379
# <re.Match object; span=(0, 52), match='3_0_dianteira 2_1_indep., 1_2_braços 0_3_sobrepos>
# found value: dianteira indep., braços sobrepostos
# found label:
# line_number: 28881
# 4_0_Elemento 3_1_elástico 2_2_Barra de 0_4_torção
# 0.5
# <re.Match object; span=(0, 0), match=''>
# found value:
# found label: elemento elástico barra de torção
# line_number: 28882
# 2_0_Traseira 1_1_Eixo 0_2_rígido
# 0.5843933793858325
# <re.Match object; span=(13, 32), match='1_1_eixo 0_2_rígido'>
# found value: eixo rígido
# found label: traseira
# line_number: 28883
# 5_0_Elemento 4_1_elástico 3_2_Feixe de 1_4_molas 0_5_semielípticas
# 0.447213595499958
# <re.Match object; span=(0, 0), match=''>
# found value:
# found label: elemento elástico feixe de molas semielípticas
# line_number: 28884
# line_number: 28885
# 2_0_Dianteiros 1_1_Disco 0_2_ventilado
# 0.5846684145800569
# <re.Match object; span=(25, 38), match='0_2_ventilado'>
# found value: ventilado
# found label: dianteiros disco
# line_number: 28886
# 1_0_Traseiros 0_1_Tambor
# 0.7071067811865476
# <re.Match object; span=(0, 0), match=''>
# found value:
# found label: traseiros tambor
# line_number: 28887
# line_number: 28888
# 1_0_Assistência 0_1_Hidráulica
# 0.7171773818295232
# <re.Match object; span=(16, 30), match='0_1_hidráulica'>
# found value: hidráulica
# found label: assistência
# line_number: 28889
# 4_0_Diâmetro de 2_2_giro 1_3_11,4 0_4_m
# 0.5133552259934893
# <re.Match object; span=(25, 33), match='1_3_11,4'>
# found value: 11,4
# found label: diâmetro de giro m
# line_number: 28890
# line_number: 28891
# 2_0_Dianteiros 1_1_225/75 0_2_R15
# 0.5943323552560901
# <re.Match object; span=(15, 25), match='1_1_225/75'>
# found value: 225/75
# found label: dianteiros r15
# line_number: 28892
# 4_0_Altura do 2_2_flanco 1_3_169 0_4_mm
# 0.5149936288655671
# <re.Match object; span=(25, 32), match='1_3_169'>
# found value: 169
# found label: altura do flanco mm
# line_number: 28893
# 2_0_Traseiros 1_1_225/75 0_2_R15
# 0.5903397645233255
# <re.Match object; span=(14, 24), match='1_1_225/75'>
# found value: 225/75
# found label: traseiros r15
# line_number: 28894
# 4_0_Altura do 2_2_flanco 1_3_169 0_4_mm
# 0.5149936288655671
# <re.Match object; span=(25, 32), match='1_3_169'>
# found value: 169
# found label: altura do flanco mm
# line_number: 28895
# 2_0_Estepe 1_1_225/75 0_2_R15
# 0.5827881940471011
# <re.Match object; span=(11, 21), match='1_1_225/75'>
# found value: 225/75
# found label: estepe r15
# line_number: 28896
# line_number: 28897
# 2_0_Comprimento 1_1_4779 0_2_mm
# 0.6102114216689141
# <re.Match object; span=(16, 24), match='1_1_4779'>
# found value: 4779
# found label: comprimento mm
# line_number: 28898
# 2_0_Largura 1_1_1700 0_2_mm
# 0.6061321657254574
# <re.Match object; span=(12, 20), match='1_1_1700'>
# found value: 1700
# found label: largura mm
# line_number: 28899
# 2_0_Distância 1_1_2750 0_2_mm
# 0.6079003263243434
# <re.Match object; span=(14, 22), match='1_1_2750'>
# found value: 2750
# found label: distância mm
# line_number: 28900
# 2_0_Altura 1_1_1700 0_2_mm
# 0.6061321657254574
# <re.Match object; span=(11, 19), match='1_1_1700'>
# found value: 1700
# found label: altura mm
# line_number: 28901
# 3_0_Bitola 2_1_dianteira 1_2_1454 0_3_mm
# 0.5131867717229572
# <re.Match object; span=(25, 33), match='1_2_1454'>
# found value: 1454
# found label: bitola dianteira mm
# line_number: 28902
# 3_0_Bitola 2_1_traseira 1_2_1399 0_3_mm
# 0.5131867717229572
# <re.Match object; span=(24, 32), match='1_2_1399'>
# found value: 1399
# found label: bitola traseira mm
# line_number: 28903
# 4_0_Tanque de 2_2_combustível 1_3_70 0_4_litros
# 0.5096654786050987
# <re.Match object; span=(30, 36), match='1_3_70'>
# found value: 70
# found label: tanque de combustível litros
# line_number: 28904
# 2_0_Caçamba 1_1_1127 0_2_litros
# 0.5902253527835326
# <re.Match object; span=(12, 20), match='1_1_1127'>
# found value: 1127
# found label: caçamba litros
# line_number: 28905
# 2_0_Peso 1_1_1735 0_2_kg
# 0.6097174030745334
# <re.Match object; span=(9, 17), match='1_1_1735'>
# found value: 1735
# found label: peso kg
# line_number: 28906
# 3_0_Carga 2_1_útil 1_2_1065 0_3_kg
# 0.5127228316413569
# <re.Match object; span=(19, 27), match='1_2_1065'>
# found value: 1065
# found label: carga útil kg
# line_number: 28907
# 4_0_Ângulo de 2_2_entrada 1_3_26 0_4_graus
# 0.5081200051135677
# <re.Match object; span=(26, 32), match='1_3_26'>
# found value: 26
# found label: ângulo de entrada graus
# line_number: 28908
# 4_0_Ângulo de 2_2_saída 1_3_22 0_4_graus
# 0.5068317029703334
# <re.Match object; span=(14, 30), match='2_2_saída 1_3_22'>
# found value: saída 22
# found label: ângulo de graus
# line_number: 28909
# 4_0_Travessia de 2_2_água 1_3_500 0_4_mm
# 0.5162842027671878
# <re.Match object; span=(0, 33), match='4_0_travessia de 2_2_água 1_3_500'>
# found value: travessia de água 500
# found label:  mm
# line_number: 28910
# 3_0_Rampa 2_1_máxima 1_2_46 0_3_graus
# 0.5152596540122774
# <re.Match object; span=(0, 27), match='3_0_rampa 2_1_máxima 1_2_46'>
# found value: rampa máxima 46
# found label:  graus
# line_number: 28911
# 5_0_Altura 4_1_mínima do 2_3_solo 1_4_160 0_5_mm
# 0.453513624583408
# <re.Match object; span=(34, 41), match='1_4_160'>
# found value: 160
# found label: altura mínima do solo mm
# line_number: 28912
# line_number: 28913
# 2_0_Área 1_1_frontal 0_2_2,46
# 0.5951651189444461
# <re.Match object; span=(21, 29), match='0_2_2,46'>
# found value: 2,46
# found label: área frontal
# line_number: 28914
# 3_0_Coef. de 1_2_arrasto 0_3_0,46
# 0.5985643182651681
# <re.Match object; span=(25, 33), match='0_3_0,46'>
# found value: 0,46
# found label: coef. de arrasto
# line_number: 28915
# 3_0_Área 2_1_frontal 1_2_corrigida 0_3_1,132
# 0.5115931324932949
# <re.Match object; span=(35, 44), match='0_3_1,132'>
# found value: 1,132
# found label: área frontal corrigida
# line_number: 28916
# line_number: 28917
# 3_0_Velocidade 2_1_máxima 1_2_158 0_3_km/h
# 0.5154197355403652
# <re.Match object; span=(26, 33), match='1_2_158'>
# found value: 158
# found label: velocidade máxima km/h
# line_number: 28918
# 3_0_Aceleração 2_1_km/h 1_2_15,4 0_3_s
# 0.5136151329328953
# <re.Match object; span=(24, 32), match='1_2_15,4'>
# found value: 15,4
# found label: aceleração km/h s
# line_number: 28919
# line_number: 28920
# 2_0_Urbano 1_1_8,5 0_2_km/l
# 0.6102114216689141
# <re.Match object; span=(11, 18), match='1_1_8,5'>
# found value: 8,5
# found label: urbano km/l
# line_number: 28921
# 2_0_Rodoviário 1_1_11,3 0_2_km/l
# 0.6102114216689141
# <re.Match object; span=(15, 23), match='1_1_11,3'>
# found value: 11,3
# found label: rodoviário km/l
# line_number: 28922
# line_number: 28923
# 2_0_Urbana 1_1_595 0_2_km
# 0.6102114216689141
# <re.Match object; span=(11, 18), match='1_1_595'>
# found value: 595
# found label: urbana km
# line_number: 28924
# 2_0_Rodoviária 1_1_791 0_2_km
# 0.6102114216689141
# <re.Match object; span=(15, 22), match='1_1_791'>
# found value: 791
# found label: rodoviária km

# %% [markdown]
# # Refining the labels

# %% [markdown]
# Let's investigate what we have in our label - value list..

# %%
label_values_list_temp = label_values_list.copy()
label_values_list_temp = [x for x in label_values_list_temp if x is not None]
i = 0
for label, value in label_values_list_temp:
    #removing stop words from label
    label_words = label.split()
    label_words = [f"{word}" if word not in stopwords.words('portuguese') else '' for i, word in enumerate(label_words)]
    label = ' '.join(label_words)
    #remove double spaces
    label = label.replace('  ', ' ')
    label_values_list_temp[i] = (label, value)
    i+=1
label_values_list_temp
label_values_temp_df = pd.DataFrame(label_values_list_temp, columns=["label", "value"])
label_values_df = label_values_temp_df.copy()
label_values_df.head(10)
# Out:
#                                label     value
# 0  renault scenic expression 1.6 16v
# 1                                ano      2007
# 2                              preço    16.975
# 3                propulsão combustão
# 4                        combustível      flex
# 5                        procedência  nacional
# 6                           garantia     1 ano
# 7                       configuração   minivan
# 8                              porte     médio
# 9                                  5   lugares

# %% [markdown]
# Quite good but.. did you realized that "lugares" (places) is being considered as a value instead of a label when there are 5 places ('5', 'lugares') ?
# Let'refine our list..

# %% [markdown]
# # Filtering found labels

# %% [markdown]
# Is understandable that labels, contrary to values, should not contain numbers, so let remove them.

# %%
# we choose to keep labels that does not contain numbers

def remove_numbers(text):
    words =  text.split()
    filtered_words = [word for word in words if re.match(r'\D*$', word)]
    filtered_text = ' '.join(filtered_words)
    #print(filtered_text)
    return(filtered_text)

# %% [markdown]
# And keep only the relevant labels..

# %%
label_values_df['filtered_label'] = label_values_df['label'].apply(lambda x: remove_numbers(x))
label_values_df = label_values_df[label_values_df["filtered_label"] != "" ]  #.dropna(subset=['filtered_label'])
label_values_df[['label', 'filtered_label']]  .head(20)
# Out:
#                                 label             filtered_label
# 0   renault scenic expression 1.6 16v  renault scenic expression
# 1                                 ano                        ano
# 2                               preço                      preço
# 3                 propulsão combustão        propulsão combustão
# 4                         combustível                combustível
# 5                         procedência                procedência
# 6                            garantia                   garantia
# 7                        configuração               configuração
# 8                               porte                      porte
# 10                             portas                     portas
# 11                            geração                    geração
# 12                         índice cnw                 índice cnw
# 13                        ranking cnw                ranking cnw
# 14                        nota leitor                nota leitor
# 15               instalação dianteiro       instalação dianteiro
# 16                         disposição                 disposição
# 17                          aspiração                  aspiração
# 18                alimentação injeção        alimentação injeção
# 19                    cilindros linha            cilindros linha
# 20          comando válvulas cabeçote  comando válvulas cabeçote

# %% [markdown]
# Now let's order by their frequency (how often those labels appear in our data)

# %%
label_values_df["filtered_label_frequency"] = label_values_df.groupby('filtered_label')['filtered_label'].transform('count')
label_freq_df = label_values_df
label_freq_df.sort_values(by="filtered_label_frequency", ascending=False, inplace=True)
label_freq_df.drop_duplicates(subset="filtered_label", keep='first', inplace=True)

# %%
pd.set_option('display.max_rows', 200)
label_freq_df[["filtered_label", "filtered_label_frequency"]].head(20)
# Out:
#                          filtered_label  filtered_label_frequency
# 1117                  equipamento série                       383
# 578                    altura flanco mm                        46
# 1916  elemento elástico mola helicoidal                        38
# 1125               equipamento opcional                        37
# 1292                              preço                        23
# 1291                                ano                        23
# 1297                       configuração                        23
# 1288                      rodoviária km                        23
# 1286                          urbana km                        23
# 1284                    rodoviário km/l                        23
# 1281                  aceleração km/h s                        23
# 1295                        procedência                        23
# 1300                             portas                        23
# 1272                       distância mm                        23
# 1298                              porte                        23
# 1294                        combustível                        23
# 1273                          altura mm                        23
# 1276          tanque combustível litros                        23
# 1278                            peso kg                        23
# 1282                        urbano km/l                        23

# %%
label_freq_df[["filtered_label", "filtered_label_frequency"]].tail(20)
# Out:
#                                 filtered_label  filtered_label_frequency
# 227                                         mm                         2
# 226                       ângulo central graus                         2
# 1535       alimentação injeção direta indireta                         2
# 1453                                     série                         2
# 1752                           honda fit lx at                         2
# 783                tração integral sob demanda                         2
# 1912  acoplamento embreagem dupla banhada óleo                         2
# 2053                           chery celer act                         1
# 2229                                     graus                         1
# 79                       toyota hilux turbo cs                         1
# 154            volkswagen amarok extreme at cd                         1
# 1162                    comando válvulas único                         1
# 936                  chevrolet corsa sedan joy                         1
# 1998               equipamento série motorista                         1
# 523         chevrolet high country turbo at cd                         1
# 1679                                     volvo                         1
# 1691                           plataforma ford                         1
# 1411                         indep., mcpherson                         1
# 748                               cadillac srx                         1
# 0                    renault scenic expression                         1

# %% [markdown]
# Sounds good but.. Did you realized that "Equipamento de Série" (meaning "Standard Equipment") has _much more_ occurence that the rest of the labels? Also, me may need to apply a threachold for labels rarely occurs (and I likyly irrelevant).
# This is understandable, since a car have several 'Standard Equipment' (as well as Optional Equipment) so we should treat those labels differently.. what about considerering them as "unit": 1 for standard equipment and 0.5 for optionals.
# Ok, let's retreive their labels (or sub-labels) then..

# %%
label_values_df = label_values_temp_df.copy()
st_equipment_labels_df =   label_values_df[label_values_df["label"] == "equipamento série" ].drop_duplicates(subset="value", keep='first').head(20)
st_equipment_labels_df
# Out:
#                  label                                      value
# 238  equipamento série                                 freios abs
# 239  equipamento série                           airbags frontais
# 240  equipamento série                           airbags laterais
# 241  equipamento série               alarme antifurto perimétrico
# 242  equipamento série               alarme antifurto volumétrico
# 243  equipamento série              câmera traseira para manobras
# 245  equipamento série     encosto de cabeça para todos ocupantes
# 246  equipamento série                   controle de estabilidade
# 247  equipamento série                         controle de tração
# 248  equipamento série                          faróis de xenônio
# 249  equipamento série             faróis com regulagem de altura
# 250  equipamento série               faróis com refletores duplos
# 251  equipamento série                          faróis de neblina
# 252  equipamento série                    luz traseira de neblina
# 253  equipamento série  repetidores laterais das luzes de direção
# 254  equipamento série              travamento central das portas
# 255  equipamento série                     luz de condução diurna
# 256  equipamento série             controle automático de descida
# 257  equipamento série             desembaçador do vidro traseiro
# 258  equipamento série    isofix para fixação de cadeira infantil

# %%
label_values_df = label_values_temp_df.copy()
optional_eq_labels_df =   label_values_df[label_values_df["label"] == "equipamento opcional" ].drop_duplicates(subset="value", keep='first').head(20)
optional_eq_labels_df
# Out:
#                      label                                   value
# 905   equipamento opcional            alarme antifurto perimétrico
# 906   equipamento opcional            alarme antifurto volumétrico
# 913   equipamento opcional     sensores de estacionamento traseiro
# 914   equipamento opcional
# 916   equipamento opcional                               ar quente
# 920   equipamento opcional  controle elétrico dos vidros traseiros
# 921   equipamento opcional        ajuste elétrico dos retrovisores
# 922   equipamento opcional                      rodas de liga leve
# 927   equipamento opcional                               cd player
# 928   equipamento opcional                             conexão usb
# 929   equipamento opcional                       conexão bluetooth
# 930   equipamento opcional                  volante multifuncional
# 931   equipamento opcional                     computador de bordo
# 1101  equipamento opcional                        airbags laterais
# 1123  equipamento opcional          retrovisor interno fotocrômico
# 1125  equipamento opcional                     teto solar elétrico
# 1126  equipamento opcional             troca de marchas no volante
# 1967  equipamento opcional               alerta de colisão frontal
# 1975  equipamento opcional                    alerta de ponto cego
# 1976  equipamento opcional              alerta de mudança de faixa

# %% [markdown]
# Ok, now let add all our potential labels and remove the duplicates.

# %%
all_labels_list = st_equipment_labels_df["value"].tolist() + optional_eq_labels_df["value"].tolist() + label_freq_df["filtered_label"].tolist()
all_labels_list_df = pd.DataFrame(all_labels_list, columns=["label"])
all_labels_list_df.head(10)
# Out:
#                                     label
# 0                              freios abs
# 1                        airbags frontais
# 2                        airbags laterais
# 3            alarme antifurto perimétrico
# 4            alarme antifurto volumétrico
# 5           câmera traseira para manobras
# 6  encosto de cabeça para todos ocupantes
# 7                controle de estabilidade
# 8                      controle de tração
# 9                       faróis de xenônio

# %%
all_labels_list_df.tail(10)
# Out:
#                                   label
# 160     volkswagen amarok extreme at cd
# 161              comando válvulas único
# 162           chevrolet corsa sedan joy
# 163         equipamento série motorista
# 164  chevrolet high country turbo at cd
# 165                               volvo
# 166                     plataforma ford
# 167                   indep., mcpherson
# 168                        cadillac srx
# 169           renault scenic expression

# %% [markdown]
# Ohh yes, we forgot: we should take off non frequent labels!...

# %%
all_labels_list = st_equipment_labels_df["value"].tolist() + optional_eq_labels_df["value"].tolist() + label_freq_df[label_freq_df["filtered_label_frequency"] > 1]["filtered_label"].tolist()
all_labels_list_df = pd.DataFrame(all_labels_list, columns=["label"])
all_labels_list_df = all_labels_list_df[all_labels_list_df['label'] != "" ].drop_duplicates()
pd.set_option('display.max_rows', 40)
all_labels_list_df
# Out:
#                                         label
# 0                                  freios abs
# 1                            airbags frontais
# 2                            airbags laterais
# 3                alarme antifurto perimétrico
# 4                alarme antifurto volumétrico
# ..                                        ...
# 152       alimentação injeção direta indireta
# 153                                     série
# 154                           honda fit lx at
# 155               tração integral sob demanda
# 156  acoplamento embreagem dupla banhada óleo
#
# [153 rows x 1 columns]

# %% [markdown]
# # Filling the table

# %% [markdown]
# Now that we have the label, let's make our data frame and fill the table with the technical specs of every car.
#
# First, let's create the dataframe.

# %%
labels_list = all_labels_list_df["label"].tolist()
labels_list.append("file_name")
cars_specs_df = pd.DataFrame(columns=labels_list )
cars_specs_df
# Out:
# Empty DataFrame
# Columns: [freios abs, airbags frontais, airbags laterais, alarme antifurto perimétrico, alarme antifurto volumétrico, câmera traseira para manobras, encosto de cabeça para todos ocupantes, controle de estabilidade, controle de tração, faróis de xenônio, faróis com regulagem de altura, faróis com refletores duplos, faróis de neblina, luz traseira de neblina, repetidores laterais das luzes de direção, travamento central das portas, luz de condução diurna, controle automático de descida, desembaçador do vidro traseiro, isofix para fixação de cadeira infantil, sensores de estacionamento traseiro, ar quente, controle elétrico dos vidros traseiros, ajuste elétrico dos retrovisores, rodas de liga leve, cd player, conexão usb, conexão bluetooth, volante multifuncional, computador de bordo, retrovisor interno fotocrômico, teto solar elétrico, troca de marchas no volante, alerta de colisão frontal, alerta de ponto cego, alerta de mudança de faixa, equipamento série, altura flanco mm, elemento elástico mola helicoidal, equipamento opcional, preço, ano, configuração, rodoviária km, urbana km, rodoviário km/l, aceleração km/h s, procedência, portas, distância mm, porte, combustível, altura mm, tanque combustível litros, peso kg, urbano km/l, velocidade máxima km/h, propulsão combustão, largura mm, diâmetro cilindro mm, índice cnw, ranking cnw, nota leitor, instalação dianteiro, disposição, aspiração, válvulas cilindro, curso pistão mm, razão compressão, cilindrada unitária, deslocamento, potência máxima cv, regime potência máx. rpm, torque máximo kgfm, regime torque máx. rpm, peso/potência kg/cv, torque específico kgfm/litro, peso/torque kg/kgfm, potência específica cv/litro, câmbio, dianteiros disco, dianteiros, traseiros, comprimento mm, comando válvulas cabeçote, cilindros linha, equipamento, assistência, carga útil kg, alimentação injeção, diâmetro giro m, tração, litros, bitola dianteira mm, bitola traseira mm, km/l, tuchos, acoplamento embreagem monodisco seco, código motor, traseira, ...]
# Index: []
#
# [0 rows x 154 columns]

# %%
text_content = []
car_specs_df_model = cars_specs_df.copy()
for file in text_files:
    car_specs_dic = {key: None for key in labels_list}

    with open(f"{file_path}{file}", 'r') as file:
        content = file.read()
        try:
            content = content.split('Ficha Técnica')[1]
            content = content.split('Fotos')[0]
            content = content.split('\n') # split the content by lines
        except:
            pass
    temp = []

    for line in content:
        #doing some basic cleaning
        #pass
        # Remove words in between brackets
        line = re.sub(r'\[.*?\]', ' ', line)

        words = line.split()
        # Remove words that contain a special character
        words = [word for word in words if all(  c == '\n' or c == '/'  or c =='.' or c == ',' for c in string.punctuation if c in word)]

        #remove stopwords from the line
        words = [word for word in words if word not in stopwords.words('portuguese')]
        cleaned_line = ' '.join(words).lower()
        cleaned_line = cleaned_line.replace('  ', ' ').strip()

        #considering the standard or optional equipment as 1 or 0.5
        equipement_value = ""

        if cleaned_line.find("equipamento série") != -1:
            equipement_value = "1"
            cleaned_line = cleaned_line.replace("equipamento série", "").strip()
        elif cleaned_line.find("equipamento opcional") != -1:
            equipement_value = "0.5"
            cleaned_line = cleaned_line.replace("equipamento opcional", "").strip()

        if equipement_value != "":
            if cleaned_line in labels_list:
                car_specs_dic[cleaned_line] = equipement_value

        else:
            # tokenize the text and the labels into words
            line_words = Counter(cleaned_line.lower().split())
            label_words = [Counter(label.lower().split()) for label in labels_list]

            # count the number of common words between the line and each label
            common_counts = [sum((line_words & label_word).values()) for label_word in label_words]

            # find the label with the most matched words of the line
            max_index = common_counts.index(max(common_counts))
            most_matched_label = labels_list[max_index]

            if max_index > 0:

                value_to_keep = cleaned_line.lower()
                for word in most_matched_label.split():
                    value_to_keep = value_to_keep.replace(word, '')
                    value_to_keep = value_to_keep.replace('  ', ' ').strip()


                car_specs_dic[most_matched_label] = value_to_keep

    if all(value is  None for value in car_specs_dic.values()):
        pass  #we do not have any information about the car
    else:
        car_specs_dic['file_name'] = os.path.basename(f"{file_path}{file}").split('.')[0]
        cars_specs_df = pd.concat([cars_specs_df, pd.DataFrame([car_specs_dic])], ignore_index=True)

        print(car_specs_dic)
# Out:
# {'freios abs': None, 'airbags frontais': None, 'airbags laterais': None, 'alarme antifurto perimétrico': None, 'alarme antifurto volumétrico': None, 'câmera traseira para manobras': None, 'encosto de cabeça para todos ocupantes': None, 'controle de estabilidade': None, 'controle de tração': None, 'faróis de xenônio': None, 'faróis com regulagem de altura': None, 'faróis com refletores duplos': None, 'faróis de neblina': None, 'luz traseira de neblina': None, 'repetidores laterais das luzes de direção': None, 'travamento central das portas': None, 'luz de condução diurna': None, 'controle automático de descida': None, 'desembaçador do vidro traseiro': None, 'isofix para fixação de cadeira infantil': None, 'sensores de estacionamento traseiro': None, 'ar quente': None, 'controle elétrico dos vidros traseiros': None, 'ajuste elétrico dos retrovisores': None, 'rodas de liga leve': None, 'cd player': None, 'conexão usb': None, 'conexão bluetooth': None, 'volante multifuncional': None, 'computador de bordo': None, 'retrovisor interno fotocrômico': None, 'teto solar elétrico': None, 'troca de marchas no volante': None, 'alerta de colisão frontal': None, 'alerta de ponto cego': None, 'alerta de mudança de faixa': None, 'equipamento série': None, 'altura flanco mm': None, 'elemento elástico mola helicoidal': None, 'equipamento opcional': None, 'preço': None, 'ano': None, 'configuração': None, 'rodoviária km': None, 'urbana km': None, 'rodoviário km/l': None, 'aceleração km/h s': '', 'procedência': None, 'portas': None, 'distância mm': None, 'porte': None, 'combustível': None, 'altura mm': None, 'tanque combustível litros': None, 'peso kg': None, 'urbano km/l': None, 'velocidade máxima km/h': None, 'propulsão combustão': None, 'largura mm': None, 'diâmetro cilindro mm': None, 'índice cnw': None, 'ranking cnw': None, 'nota leitor': None, 'instalação dianteiro': None, 'disposição': None, 'aspiração': None, 'válvulas cilindro': None, 'curso pistão mm': None, 'razão compressão': None, 'cilindrada unitária': None, 'deslocamento': None, 'potência máxima cv': None, 'regime potência máx. rpm': None, 'torque máximo kgfm': None, 'regime torque
': 'flex', 'altura mm': None, 'tanque combustível litros': '410', 'peso kg': '1250', 'urbano km/l': '6,4', 'velocidade máxima km/h': '181', 'propulsão combustão': '', 'largura mm': '1719', 'diâmetro cilindro mm': '79,5', 'índice cnw': '94,01', 'ranking cnw': '10642', 'nota leitor': '8,5', 'instalação dianteiro': '', 'disposição': 'transversal', 'aspiração': 'natural', 'válvulas cilindro': '4', 'curso pistão mm': '80,5', 'razão compressão': '', 'cilindrada unitária': '400', 'deslocamento': '1598', 'potência máxima cv': '110', 'regime potência máx. rpm': '5750', 'torque máximo kgfm': '15,1', 'regime torque máx. rpm': '3750', 'peso/potência kg/cv': '10,87', 'torque específico kgfm/litro': '10,0', 'peso/torque kg/kgfm': '78,1', 'potência específica cv/litro': '72,0', 'câmbio': 'manual', 'dianteiros disco': '185/65 r15', 'dianteiros': None, 'traseiros': None, 'comprimento mm': '4169', 'comando válvulas cabeçote': 'duplo', 'cilindros linha': '4', 'equipamento': None, 'assistência': 'hidráulica', 'carga útil kg': '550', 'alimentação injeção': 'multiponto', 'diâmetro giro m': '10,7', 'tração': None, 'litros': None, 'bitola dianteira mm': 'indep., mcpherson', 'bitola traseira mm': None, 'km/l': None, 'tuchos': 'hidráulicos', 'acoplamento embreagem monodisco seco': '', 'código motor': 'k4m', 'traseira': None, 'geração': '1', 'km': None, 'coef. arrasto': '0,33', 'traseiros tambor': '', 'área frontal corrigida': '0,779', 'área frontal': None, 'garantia': None, 'reboque freio kg': None, 'acionam. comando correia dentada': '', 'estepe': None, 'plataforma': None, 'altura mínima solo mm': None, 'rotação máxima rpm': '6500', 'código câmbio': 'jh3', 'cv': None, 'kgfm': None, 'marchas': None, 'traseiros disco': None, 'garantia anos': None, 'acionam. comando': None, 'código': None, 'traseira indep.,': 'braço arrastado', 'ângulo entrada graus': None, 'caçamba litros': None, 'volkswagen': None, 'elemento elástico feixe molas semielípticas': None, 'equipamento série cintos': None, 'acoplamento conversor torque': None, 'tração integral': None, 'revisões preços tabelados': None, 'diâmetro giro': None, 'lugares': '5', 'revisões': None, 'ângulo graus': None, 'equipamento série ajuste altura': None, 'variação comando admissão escape': None, 'assistência assistida': None, 'ângulo saída graus': None, 'elemento elástico barra torção': '', 'fiat': None, 'equ ...
# {'freios abs': None, 'airbags frontais': None, 'airbags laterais': None, 'alarme antifurto perimétrico': None, 'alarme antifurto volumétrico': None, 'câmera traseira para manobras': 'eixo rígido', 'encosto de cabeça para todos ocupantes': None, 'controle de estabilidade': None, 'controle de tração': None, 'faróis de xenônio': None, 'faróis com regulagem de altura': None, 'faróis com refletores duplos': None, 'faróis de neblina': None, 'luz traseira de neblina': None, 'repetidores laterais das luzes de direção': '', 'travamento central das portas': '2', 'luz de condução diurna': None, 'controle automático de descida': None, 'desembaçador do vidro traseiro': None, 'isofix para fixação de cadeira infantil': None, 'sensores de estacionamento traseiro': None, 'ar quente': None, 'controle elétrico dos vidros traseiros': '205/70 r16', 'ajuste elétrico dos retrovisores': None, 'rodas de liga leve': None, 'cd player': None, 'conexão usb': None, 'conexão bluetooth': None, 'volante multifuncional': None, 'computador de bordo': None, 'retrovisor interno fotocrômico': None, 'teto solar elétrico': None, 'troca de marchas no volante': '5', 'alerta de colisão frontal': None, 'alerta de ponto cego': None, 'alerta de mudança de faixa': None, 'equipamento série': None, 'altura flanco mm': '1795', 'elemento elástico mola helicoidal': '', 'equipamento opcional': None, 'preço': '102.200', 'ano': 'garantia 1', 'configuração': 'picape', 'rodoviária km': '1120', 'urbana km': '800', 'rodoviário km/l': '14', 'aceleração km/h s': '19,9', 'procedência': 'importado', 'portas': None, 'distância mm': '3085', 'porte': 'médio', 'combustível': 'diesel', 'altura mm': None, 'tanque combustível litros': '80', 'peso kg': '1715', 'urbano km/l': '10', 'velocidade máxima km/h': '154', 'propulsão combustão': '', 'largura mm': '1760', 'diâmetro cilindro mm': '92', 'índice cnw': '13,77', 'ranking cnw': '19997', 'nota leitor': '7,0', 'instalação dianteiro': '', 'disposição': 'longitudinal', 'aspiração': 'turbocompressor', 'válvulas cilindro': '4', 'curso pistão mm': '93,8', 'razão compressão': '', 'cilindrada unitária': '624', 'deslocamento': '2494', 'potência máxima cv': '102', 'regime potência máx. rpm': '3600', 'torque máximo kgfm': '26,5', 'regime torque máx. rpm': '1600', 'peso/potência kg/cv': '16,81', 'torque específico kgfm/litro': '10,6', 'peso/torque kg/kgfm': '64,7', 'potência específica cv/litro': '40,9', 'câmbio': 'manual', 'dianteiros disco': '205/70 r16', 'dianteiros': None, 'traseiros': None, 'comprimento mm': '5255', 'comando válvulas cabeçote': 'duplo', 'cilindros linha': '4', 'equipamento': None, 'assistência': 'hidráulica', 'carga útil kg': '1095', 'alimentação injeção': None, 'diâmetro giro m': '11,8', 'tração': None, 'litros': None, 'bitola dianteira mm': 'indep., braços sobrepostos', 'bitola traseira mm': None, 'km/l': None, 'tuchos': None, 'acoplamento embreagem monodisco seco': '', 'código motor': '', 'traseira': None, 'geração': '7', 'km': None, 'coef. arrasto': '0,37', 'traseiros tambor': '', 'área frontal corrigida': '0,995', 'área frontal': None, 'garantia': None, 'reboque freio kg': None, 'acionam. comando correia dentada': '', 'estepe': '205/70 r16', 'plataforma': 'imv', 'altura mínima solo mm': '212', 'rotação máxima rpm': None, 'código câmbio': None, 'cv': None, 'kgfm': None, 'marchas': None, 'traseiros disco': None, 'garantia anos': None, 'acionam. comando': None, 'código': None, 'traseira indep.,': None, 'ângulo entrada graus': '21', 'caçamba litros': '1580', 'volkswagen': None, 'elemento elástico feixe molas semielípticas': '', 'equipamento série cintos': None, 'acoplamento conversor torque': None, 'tração integral': 'temporária', 'revisões preços tabelados': None, 'diâmetro giro': None, 'lugares': '2', 'revisões': None, 'ângulo graus': None, 'equipamento série ajuste altura': None, 'variação comando admissão escape': None, 'assistência assistida': None, 'ângulo saída graus': '18', 'elemento elástico barra torção': None, 'fiat': None, ' ...
ustão': '', 'largura mm': '1621', 'diâmetro cilindro mm': '81', 'índice cnw': '56,41', 'ranking cnw': '15667', 'nota leitor': '7,0', 'instalação dianteiro': '', 'disposição': 'longitudinal', 'aspiração': 'natural', 'válvulas cilindro': '2', 'curso pistão mm': '86,4', 'razão compressão': '', 'cilindrada unitária': '445', 'deslocamento': '1781', 'potência máxima cv': '99', 'regime potência máx. rpm': '5250', 'torque máximo kgfm': '15,5', 'regime torque máx. rpm': '3000', 'peso/potência kg/cv': '9,95', 'torque específico kgfm/litro': '8,7', 'peso/torque kg/kgfm': '63,5', 'potência específica cv/litro': '55,6', 'câmbio': 'manual', 'dianteiros disco': '185/60 r14', 'dianteiros': None, 'traseiros': None, 'comprimento mm': '4441', 'comando válvulas cabeçote': 'único', 'cilindros linha': '4', 'equipamento': None, 'assistência': 'hidráulica', 'carga útil kg': '700', 'alimentação injeção': 'multiponto', 'diâmetro giro m': '10,6', 'tração': None, 'litros': None, 'bitola dianteira mm': 'indep., mcpherson', 'bitola traseira mm': None, 'km/l': None, 'tuchos': 'hidráulicos', 'acoplamento embreagem monodisco seco': '', 'código motor': '', 'traseira': None, 'geração': '3', 'km': None, 'coef. arrasto': None, 'traseiros tambor': '', 'área frontal corrigida': None, 'área frontal': None, 'garantia': None, 'reboque freio kg': None, 'acionam. comando correia dentada': '', 'estepe': '185/60 r14', 'plataforma': 'ab9', 'altura mínima solo mm': None, 'rotação máxima rpm': None, 'código câmbio': None, 'cv': None, 'kgfm': None, 'marchas': None, 'traseiros disco': None, 'garantia anos': None, 'acionam. comando': None, 'código': None, 'traseira indep.,': None, 'ângulo entrada graus': None, 'caçamba litros': '860', 'volkswagen': 'saveiro fun 1.8', 'elemento elástico feixe molas semielípticas': None, 'equipamento série cintos': None, 'acoplamento conversor torque': None, 'tração integral': None, 'revisões preços tabelados': None, 'diâmetro giro': None, 'lugares': '2', 'revisões': None, 'ângulo graus': None, 'equipamento série ajuste altura': None, 'variação comando admissão escape': None, 'assistência assistida': None, 'ângulo saída graus': None, 'elemento elástico barra torção': None, 'fiat':  ...
# {'freios abs': None, 'airbags frontais': None, 'airbags laterais': None, 'alarme antifurto perimétrico': None, 'alarme antifurto volumétrico': None, 'câmera traseira para manobras': 'eixo torção', 'encosto de cabeça para todos ocupantes': None, 'controle de estabilidade': None, 'controle de tração': 'dianteira', 'faróis de xenônio': None, 'faróis com regulagem de altura': None, 'faróis com refletores duplos': None, 'faróis de neblina': None, 'luz traseira de neblina': None, 'repetidores laterais das luzes de direção': '', 'travamento central das portas': '2', 'luz de condução diurna': None, 'controle automático de descida': None, 'desembaçador do vidro traseiro': None, 'isofix para fixação de cadeira infantil': None, 'sensores de estacionamento traseiro': None, 'ar quente': None, 'controle elétrico dos vidros traseiros': '155/80 r13', 'ajuste elétrico dos retrovisores': None, 'rodas de liga leve': None, 'cd player': None, 'conexão usb': None, 'conexão bluetooth': None, 'volante multifuncional': None, 'computador de bordo': None, 'retrovisor interno fotocrômico': None, 'teto solar elétrico': None, 'troca de marchas no volante': '4', 'alerta de colisão frontal': None, 'alerta de ponto cego': None, 'alerta de mudança de faixa': None, 'equipamento série': None, 'altura flanco mm': '1355', 'elemento elástico mola helicoidal': '', 'equipamento opcional': None, 'preço': '7.301', 'ano': 'garantia 1', 'configuração': 'cupê', 'rodoviária km': '600', 'urbana km': '420', 'rodoviário km/l': '10', 'aceleração km/h s': '13,5', 'procedência': 'nacional', 'portas': None, 'distância mm': '2470', 'porte': 'médio', 'combustível': 'álcool', 'altura mm': None, 'tanque combustível litros': '362', 'peso kg': '920', 'urbano km/l': '7', 'velocidade máxima km/h': '160', 'propulsão combustão': '', 'largura mm': '1600', 'diâmetro cilindro mm': '81', 'índice cnw': '80,79', 'ranking cnw': '11943', 'nota leitor': '6,8', 'instalação dianteiro': '', 'disposição': 'longitudinal', 'aspiração': 'natural', 'válvulas cilindro': '2', 'curso pistão mm': '77,4', 'razão compressão': '', 'cilindrada unitária': '399', 'deslocamento': '1596', 'potência máxima cv': '85', 'regime potência máx. rpm': '5600', 'torque máximo kgfm': '12,65', 'regime torque máx. rpm': '3000', 'peso/potência kg/cv': '10,82', 'torque específico kgfm/litro': '7,9', 'peso/torque kg/kgfm': '72,7', 'potência específica cv/litro': '53,3', 'câmbio': 'manual', 'dianteiros disco': '155/80 r13', 'dianteiros': None, 'traseiros': None, 'comprimento mm': '4290', 'comando válvulas cabeçote': 'único', 'cilindros linha': '4', 'equipamento': None, 'assistência': None, 'carga útil kg': '450', 'alimentação injeção': None, 'diâmetro giro m': '10,2', 'tração': None, 'litros': None, 'bitola dianteira mm': '1340', 'bitola traseira mm': '1342', 'km/l': None, 'tuchos': 'mecânicos', 'acoplamento embreagem monodisco seco': '', 'código motor': '', 'traseira': None, 'geração': '1', 'km': None, 'coef. arrasto': None, 'traseiros tambor': '', 'área frontal corrigida': None, 'área frontal': None, 'garantia': None, 'reboque freio kg': None, 'acionam. comando correia dentada': '', 'estepe': '155/80 r13', 'plataforma': 'b1', 'altura mínima solo mm': '140', 'rotação máxima rpm': None, 'código câmbio': None, 'cv': None, 'kgfm': None, 'marchas': None, 'traseiros disco': None, 'garantia anos': None, 'acionam. comando': None, 'código': None, 'traseira indep.,': None, 'ângulo entrada graus': None, 'caçamba litros': None, 'volkswagen': 'passat special 1.6', 'elemento elástico feixe molas semielípticas': None, 'equipamento série cintos': None, 'acoplamento conversor torque': None, 'tração integral': None, 'revisões preços tabelados': None, 'diâmetro giro': None, 'lugares': '5', 'revisões': None, 'ângulo graus': None, 'equipamento série ajuste altura': None, 'variação comando admissão escape': None, 'assistência assistida': 'não', 'ângulo saída graus': None, 'elemento elástico barra torção': None, 'fiat': None, 'equipamento série controle': ...
': None, 'bitola dianteira mm': None, 'bitola traseira mm': None, 'km/l': None, 'tuchos': None, 'acoplamento embreagem monodisco seco': None, 'código motor': None, 'traseira': None, 'geração': None, 'km': None, 'coef. arrasto': None, 'traseiros tambor': None, 'área frontal corrigida': None, 'área frontal': None, 'garantia': None, 'reboque freio kg': None, 'acionam. comando correia dentada': None, 'estepe': None, 'plataforma': None, 'altura mínima solo mm': None, 'rotação máxima rpm': None, 'código câmbio': None, 'cv': None, 'kgfm': None, 'marchas': None, 'traseiros disco': None, 'garantia anos': None, 'acionam. comando': None, 'código': None, 'traseira indep.,': None, 'ângulo entrada graus': None, 'caçamba litros': None, 'volkswagen': None, 'elemento elástico feixe molas semielípticas': None, 'equipamento série cintos': None, 'acoplamento conversor torque': None, 'tração integral': None, 'revisões preços tabelados': None, 'diâmetro giro': None, 'lugares': None, 'revisões': None, 'ângulo graus': None, 'equipamento série ajuste altura': None, 'variação comando admissão escape': None, 'assistência assistida': None, 'ângulo saída graus': None, 'elemento elástico barra torção': None, 'fiat': None, 'equipamento série controle': None, 'equipamento opcional automático': None, 'alimentação carburador': None, 'cilindros': None, 'equipamento série luz': None, 'chevrolet  ...
# ...
#    freios abs airbags frontais airbags laterais alarme antifurto perimétrico  \
# 0        None             None             None                         None
# 1        None             None             None                         None
# 2        None             None             None                         None
# 3           1                1                1                            1
# 4        None             None             None                         None
# 5        None             None             None                         None
# 6        None             None             None                         None
# 7        None             None             None                         None
# 8        None             None             None                         None
# 9        None             None             None                         None
# 10       None             None             None                         None
# 11          1                1                1                            1
# 12       None             None             None                         None
# 13       None             None             None                         None
# 14          1                1             None                          0.5
# 15       None             None             None                         None
# 16          1                1              0.5                          0.5
# 17       None             None             None                         None
# 18       None             None             None                         None
# 19       None             None             None                         None
# 20       None             None             None                         None
# 21       None             None             None                         None
# 22       None             None             None                         None
# 23          1                1                1                            1
# 24       None             None             None                         None
# 25       None             None             None                         None
# 26          1                1             None                            1
# 27          1                1                1                            1
# 28          1                1             None                            1
# 29       None             None             None                         None
#
#    alarme antifurto volumétrico câmera traseira para manobras  \
# 0                          None                          None
# 1                          None                          None
# 2                          None                   eixo rígido
# 3                             1                   eixo rígido
# 4                          None                          None
# 5                          None                          None
# 6                          None                   eixo torção
# 7                          None                   eixo torção
# 8                          None                          None
# 9                          None                   eixo torção
# 10                         None                          None
# 11                         None                   eixo rígido
# 12                         None                   eixo torção
# 13                         None                          None
# 14                          0.5                   eixo torção
# 15                         None                   eixo torção
# 16                         None                   eixo torção
# 17                         None                   eixo rígido
# 18                         None                   eixo torção
# 19                         None                   eixo rígido
# 20                         None                          None
# 21                         None                          None
# 22                         None                          None
# 23                            1                          None
# 24                         None                          None
# 25                         None                          None
# 26                         None                   eixo torção
# 27                            1                          None
# 28                         None                   eixo torção
# 29                         None                   eixo rígido
#
#    encosto de cabeça para todos ocupantes controle de estabilidade  \
# 0                                    None                     None
# 1                                    None                     None
# 2                                    None                     None
# 3                                    None                     None
# 4                                    None                     None
# 5                                    None                     None
# 26                                None  None             1.5
# 27                                  in  None            None
# 28                                None  None            None
# 29                                      None            None
#
#    tração integral sob demanda acoplamento embreagem dupla banhada óleo  \
# 0                         None                                     None
# 1                         None                                     None
# 2                         None                                     None
# 3                         None                                     None
# 4                         None                                     None
# 5                         None                                     None
# 6                         None                                     None
# 7                         None                                     None
# 8                         None                                     None
# 9                         None                                     None
# 10                        None                                     None
# 11                        None                                     None
# 12                        None                                     None
# 13                                                                 None
# 14                        None                                     None
# 15                        None                                     None
# 16                        None                                     None
# 17                        None                                     None
# 18                        None                                     None
# 19                        None                                     None
# 20                        None                                     None
# 21                        None                                     None
# 22                        None                                     None
# 23
# 24                        None                                     None
# 25                        None                                     None
# 26                        None                                     None
# 27                        None
# 28                        None                                     None
# 29                        None                                     None
#
#    file_name
# 0      22397
# 1      16273
# 2      13249
# 3      21550
# 4      22013
# 5      23487
# 6      14521
# 7      14910
# 8        934
# 9      14426
# 10     22821
# 11      9066
# 12      2087
# 13      5011
# 14      1667
# 15      6068
# 16      3122
# 17     19168
# 18     21872
# 19     11505
# 20     14847
# 21     12923
# 22     22962
# 23     15261
# 24      1185
# 25      3034
# 26      2039
# 27      4564
# 28      5563
# 29     15147
#
# [30 rows x 154 columns]

# %%
cars_specs_df.tail()
# Out:
#    freios abs airbags frontais airbags laterais alarme antifurto perimétrico  \
# 25       None             None             None                         None
# 26          1                1             None                            1
# 27          1                1                1                            1
# 28          1                1             None                            1
# 29       None             None             None                         None
#
#    alarme antifurto volumétrico câmera traseira para manobras  \
# 25                         None                          None
# 26                         None                   eixo torção
# 27                            1                          None
# 28                         None                   eixo torção
# 29                         None                   eixo rígido
#
#    encosto de cabeça para todos ocupantes controle de estabilidade  \
# 25                                   None                     None
# 26                                   None                     None
# 27                                   None                     None
# 28                                   None                     None
# 29                                   None                     None
#
#    controle de tração faróis de xenônio  ... equipamento série luz  \
# 25          dianteira              None  ...                  None
# 26          dianteira              None  ...                  None
# 27          dianteira              None  ...                  None
# 28          dianteira              None  ...                  None
# 29               None              None  ...                  None
#
#              chevrolet cs    mm ângulo central graus  \
# 25                   None  None                 None
# 26                   None  None                 None
# 27                   None  None                 None
# 28                   None  None                 None
# 29  s10 de luxe 2.5 turbo  None                 None
#
#    alimentação injeção direta indireta série honda fit lx at  \
# 25                                None  None            None
# 26                                None  None             1.5
# 27                                  in  None            None
# 28                                None  None            None
# 29                                      None            None
#
#    tração integral sob demanda acoplamento embreagem dupla banhada óleo  \
# 25                        None                                     None
# 26                        None                                     None
# 27                        None
# 28                        None                                     None
# 29                        None                                     None
#
#    file_name
# 25      3034
# 26      2039
# 27      4564
# 28      5563
# 29     15147
#
# [5 rows x 154 columns]

# %% [markdown]
# # Final considerations

# %% [markdown]
# In this example, we explored how to structure a series of semi-structured text files into a structured table using a TfId technique coupled with a common count tokenizer technique to fill the table, although these techniques may work well in our case, is possible to improve this technique with an RNN model for supervised learning in order to better determine the threshold to be used by the system, but we will leave this for another time, after all, all article should reach an end.
#
# Voilá!
