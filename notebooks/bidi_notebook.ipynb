# %%
import numpy as np
import pandas as pd

def clean_data(df: pd.DataFrame) -> pd.DataFrame:
    """ Receive dataframe. remove Nan's, remove columns that are usless """
    #Too many features with NaN's, remove columns which have more then 15000 Nan'n in column
    filtered_columns = df.columns[df.isna().sum() < 15000]
    filtered_df = df[filtered_columns]

    #remove some rows with a lot of Nan's
    test_filtered_df = filtered_df.dropna(subset='Acceleration')

    #columns that are usless.
    column_to_remove = ['Assistance', 'Aspiration', 'Rear tires', 'Spare tire', 'Front tires',
                    'Urban autonomy', 'Generation', 'Front suspension', 'Rear suspension', 'Coupling', 'Valve command',
                     'Disposition', 'Cylinders', 'Elastic element', 'Ipva R', 'Frontal area A', 'Engine code',
                    'Traction', 'Installation', 'Road autonomy', 'Engine power supply', 'Engine control activation',
                    'Gear change code', 'Corrected frontal area', 'Platform']

    # remove usless columns
    new_filtered_df = test_filtered_df.drop(columns=column_to_remove)
    #return clean dataframe
    return new_filtered_df


def preprocess(df: pd.DataFrame) -> pd.DataFrame:
    ''' Receive dataframe. Transform values to numbers '''

    # columns that will be transformed same: Nan = 0 / standart equipment, optinal equipment = 1
    columns_to_transform = ['Hot air', 'Rev counter', 'Assisted direction', 'ABS brakes', 'Rear window', 'Central locking of the doors',
                        'Headrest for all occupants', 'Electric rearview mirror adjustment', 'Air conditioning',
                        'Bluetooth connection', 'Frontal Airbags', 'Steering wheel adjustment height',
                        'Electric front window control', 'Multifunctional steering wheel', 'Driver s seat with height adjustment',
                        'On board computer', 'Light in the trunk', 'Alloy wheels', 'USB connection', 'Radio',
                        'Folding rear seat', 'Perimeter anti theft alarm', 'Cooling liquid thermometer']
    df[columns_to_transform] = df[columns_to_transform].applymap(lambda x: 0 if pd.isnull(x) else 1)

    ########################################Preprocess [Acceleration]#################################################################
    # Preprocess Acceleration (0100 km/h 3,8 s = 3.8)
    df['Acceleration'] = df['Acceleration'].str.extract(r'(\d+\,\d+)')
    # Replace ',' with '.' and convert to numeric
    df['Acceleration'] = df['Acceleration'].str.replace(',', '.').astype(float)
    # Rename Column
    df = df.rename(columns={'Acceleration': 'Acceleration 0100 km/h in S'})

    ##########################################Preproces values with mm/kg/cm/ ETC ####################################################
    #function to remove strings (mm/kg/cm/) and transform to floats
    def extract_float_value(value):
        try:
            if isinstance(value, float):
                return value
            else:
                float_value = value.split()[0].replace(',', '.')
                return float(float_value)
        except (ValueError, IndexError):
            return np.nan

    #transforming
    for column in df[['Weight/Torque', 'Weight', 'Weight/power', 'Max power regime.', 'Cylinder diameter',
                      'Fuel tank', 'Specific power', 'Maximum power', 'Length', 'Maximum torque', 'Width', 'Height',
                      'Specific torque', 'Minimum height from the ground', 'Piston course', 'Front gauge', 'Displacement',
                      'Turns diameter', 'Rear gauge', 'Length between the axis', 'Maximum speed', 'Road consumption',
                      'Max torque regime', 'Car payload', 'Sidewall height', 'Unit displacement', 'Trunk', 'Urban']]:
        df[column] = df[column].apply(extract_float_value)
    #################################################################################################################################


    return df

# %%
df = pd.read_csv('/Users/bididudy/code/marcnaweb/car_recommendation_engine/raw_data/categorized_car_features.csv')
# Out:
# /var/folders/ld/s5_rrf_n32q9rltztl0sz_fh0000gn/T/ipykernel_36807/151809030.py:1: DtypeWarning: Columns (35,43,54,76,77,78,79,84,85,86,87,88,89,90,91,93,94,95,96,98,99,100,101,118,119,139,145,146,154,157,175,180,189,197,204,214,235,239,241,249,263,269,280,281) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/bididudy/code/marcnaweb/car_recommendation_engine/raw_data/categorized_car_features.csv')

# %%
df=clean_data(df)
df
# Out:
#        Carcode Weight/Torque   Weight                   Fuel Weight/power  \
# 0            1  24,9 kg/kgfm  1650 kg               Gasoline   2,85 kg/cv
# 1            2  97,1 kg/kgfm   825 kg               Gasoline  15,00 kg/cv
# 2            3  67,6 kg/kgfm  1170 kg               Gasoline  10,09 kg/cv
# 4            5  59,9 kg/kgfm  1282 kg               Gasoline   8,55 kg/cv
# 5            6  71,9 kg/kgfm  1200 kg               Gasoline   9,09 kg/cv
# ...        ...           ...      ...                    ...          ...
# 23881    23884  63,4 kg/kgfm  1110 kg  Flex alcohol/gasoline   9,25 kg/cv
# 23882    23885  63,4 kg/kgfm  1110 kg  Flex alcohol/gasoline   9,25 kg/cv
# 23890    23893  63,4 kg/kgfm  1110 kg  Flex alcohol/gasoline   9,25 kg/cv
# 23902    23905  63,2 kg/kgfm  2192 kg                 Diesel  15,66 kg/cv
# 23903    23906  63,2 kg/kgfm  2192 kg                 Diesel  15,66 kg/cv
#
#       Max power regime. Cylinder diameter   Fuel tank  \
# 0              7500 rpm             87 mm  100 litros
# 1              5500 rpm             70 mm   50 litros
# 2              5200 rpm             86 mm   52 litros
# 4              5700 rpm             81 mm   55 litros
# 5              6500 rpm             82 mm   50 litros
# ...                 ...               ...         ...
# 23881          6000 rpm             71 mm   50 litros
# 23882          6000 rpm             71 mm   50 litros
# 23890          6000 rpm             71 mm   50 litros
# 23902          3750 rpm             85 mm   90 litros
# 23903          3750 rpm             85 mm   90 litros
#
#       Steering wheel adjustment height  Specific power  ... Sidewall height  \
# 0                                  NaN   93,5 cv/litro  ...          101 mm
# 1                                  NaN   55,1 cv/litro  ...          116 mm
# 2                                  NaN   58,1 cv/litro  ...          113 mm
# 4                                  NaN   84,2 cv/litro  ...          123 mm
# 5                                  NaN   75,6 cv/litro  ...          107 mm
# ...                                ...             ...  ...             ...
# 23881                              NaN  120,2 cv/litro  ...          107 mm
# 23882               Standard equipment  120,2 cv/litro  ...          107 mm
# 23890               Standard equipment  120,2 cv/litro  ...          107 mm
# 23902                              NaN   64,2 cv/litro  ...          169 mm
# 23903                              NaN   64,2 cv/litro  ...          169 mm
#
#       Provenance   On board computer  Light in the trunk   Settings  \
# 0       Imported                 NaN                 NaN      Coupe
# 1       National                 NaN                 NaN  Hatchback
# 2       National                 NaN                 NaN  Hatchback
# 4       National                 NaN                 NaN  Hatchback
# 5       National                 NaN                 NaN  Hatchback
# ...          ...                 ...                 ...        ...
# 23881   National  Standard equipment                 NaN  Hatchback
# 23882   National  Standard equipment                 NaN  Hatchback
# 23890   National  Standard equipment  Standard equipment  Hatchback
# 23902   Imported  Standard equipment  Standard equipment        Van
# 23903   Imported  Standard equipment  Standard equipment        Van
#
#       Unit displacement         Trunk      USB connection       Urban  \
# 0              516 cm^3     50 litros                 NaN    2,4 km/l
# 1              250 cm^3    290 litros                 NaN     10 km/l
# 2              500 cm^3    370 litros                 NaN    7,2 km/l
# 4              445 cm^3    330 litros                 NaN    6,8 km/l
# 5              437 cm^3    370 litros                 NaN      9 km/l
# ...                 ...           ...                 ...         ...
# 23881          333 cm^3    300 litros  Standard equipment  8,3 km/l A
# 23882          333 cm^3    300 litros  Standard equipment  8,3 km/l A
# 23890          333 cm^3    300 litros  Standard equipment    9 km/l A
# 23902          545 cm^3  11500 litros  Standard equipment     10 km/l
# 23903          545 cm^3  13000 litros  Standard equipment     10 km/l
#
#                     Radio
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 4                     NaN
# 5                     NaN
# ...                   ...
# 23881  Standard equipment
# 23882  Standard equipment
# 23890  Standard equipment
# 23902  Optional equipment
# 23903  Optional equipment
#
# [20708 rows x 67 columns]

# %%
df=preprocess(df)
# Out:
# /var/folders/ld/s5_rrf_n32q9rltztl0sz_fh0000gn/T/ipykernel_36807/1036484295.py:36: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[columns_to_transform] = df[columns_to_transform].applymap(lambda x: 0 if pd.isnull(x) else 1)

# %%
def process_guarantee_column(df):
    new_df = df.copy()

    # Remove 'year' or 'years' from 'Guarantee' column values
    new_df['Guarantee'] = new_df['Guarantee'].str.replace(r'\s*years?\s*', '', regex=True)

    # Rename the column to 'Guarantee in years'
    new_df = new_df.rename(columns={'Guarantee': 'Guarantee in years'})

    return new_df

# %%
df=process_guarantee_column(df)

# %%
import os

# Define the file path to the 'Downloads' directory
downloads_directory = os.path.expanduser('~/Downloads')

# Specify the full file path for saving the CSV file
csv_file_path = os.path.join(downloads_directory, 'df_7.csv')

# Save the DataFrame to the CSV file
df.to_csv(csv_file_path, index=False)

# %%
df_object_columns = df.select_dtypes(include=['object'])
df_object_columns
# Out:
#                         Fuel              Car size Compression ratio  \
# 0                   Gasoline                Grande             10,71
# 1                   Gasoline  Compact and portable              9,51
# 2                   Gasoline                Medium              9,81
# 4                   Gasoline                Medium              9,51
# 5                   Gasoline                Medium             10,31
# ...                      ...                   ...               ...
# 23881  Flex alcohol/gasoline  Compact and portable             10,51
# 23882  Flex alcohol/gasoline  Compact and portable             10,51
# 23890  Flex alcohol/gasoline  Compact and portable             10,51
# 23902                 Diesel                Grande               161
# 23903                 Diesel                Grande               161
#
#           Tuching Guarantee in years Drag coefficient  Propulsion Car gearbox  \
# 0             NaN                  1             0,33  Combustion      Manual
# 1      Mechanical                  1             0,36  Combustion      Manual
# 2           Hydro                  1              0,3  Combustion      Manual
# 4           Hydro                  1             0,31  Combustion      Manual
# 5           Hydro                  1              NaN  Combustion      Manual
# ...           ...                ...              ...         ...         ...
# 23881  Mechanical                  5              NaN  Combustion   Automatic
# 23882  Mechanical                  5              NaN  Combustion   Automatic
# 23890  Mechanical                  5              NaN  Combustion   Automatic
# 23902         NaN                  1              NaN  Combustion      Manual
# 23903         NaN                  1              NaN  Combustion      Manual
#
#        Price R Devaluation CNW Index Reader score Provenance   Settings
# 0      811.249         2,5      6,93          8,5   Imported      Coupe
# 1       11.577        8,27     64,45          8,8   National  Hatchback
# 2       16.585        2,94     77,95          8,4   National  Hatchback
# 4       33.527       15,02     54,23          9,2   National  Hatchback
# 5       12.087        8,27    111,47          7,4   National  Hatchback
# ...        ...         ...       ...          ...        ...        ...
# 23881  102.090         NaN    973,96          7,0   National  Hatchback
# 23882  107.390         NaN    993,45          7,0   National  Hatchback
# 23890  117.090         NaN  1.001,37          7,0   National  Hatchback
# 23902  245.990         NaN    293,95          7,0   Imported        Van
# 23903  249.990         NaN    294,91          7,0   Imported        Van
#
# [20708 rows x 14 columns]

# %% [markdown]
# ## Converting string to float

# %%
def convert_columns_to_float(df, columns):
    """
    Replace commas with dots in specified columns and convert them to float.

    Parameters:
    - df: pandas.DataFrame.
    - columns: List of column names to be converted.

    Returns:
    - DataFrame with the specified columns converted to float.
    """
    for col in columns:
        # Check if the column exists in the DataFrame
        if col in df.columns:
            # Replace commas with dots and convert to float, coercing errors to NaN
            df[col] = pd.to_numeric(df[col].astype(str).str.replace(',', '.'), errors='coerce')
        else:
            print(f"Column '{col}' not found in DataFrame.")
    return df

# %%
columns_to_convert = ['Carcode','Guarantee in years','Drag coefficient', 'Price R', 'Devaluation', 'CNW Index', 'Reader score','Compression ratio']
cleaned_data = convert_columns_to_float(df=df, columns=columns_to_convert)

# %%
cleaned_data.columns
# Out:
# Index(['Carcode', 'Weight/Torque', 'Weight', 'Fuel', 'Weight/power',
#        'Max power regime.', 'Cylinder diameter', 'Fuel tank',
#        'Steering wheel adjustment height', 'Specific power',
#        'Multifunctional steering wheel',
#        'Driver s seat with height adjustment', 'Alloy wheels', 'Maximum power',
#        'Car size', 'Hot air', 'Rear window',
#        'Electric rearview mirror adjustment', 'Air conditioning',
#        'Frontal Airbags', 'Electric front window control', 'Folding rear seat',
#        'ABS brakes', 'Central locking of the doors',
#        'Perimeter anti theft alarm', 'Bluetooth connection',
#        'Acceleration 0100 km/h in S', 'Length', 'Maximum torque', 'Width',
#        'Rev counter', 'Compression ratio', 'Assisted direction', 'Tuching',
#        'Guarantee in years', 'Drag coefficient', 'Height', 'Specific torque',
#        'Minimum height from the ground', 'Propulsion', 'Piston course',
#        'Car gearbox', 'Price R', 'Headrest for all occupants', 'Front gauge',
#        'Displacement', 'Cooling liquid thermometer', 'Turns diameter',
#        'Rear gauge', 'Length between the axis', 'Maximum speed', 'Devaluation',
#        'Road consumption', 'Max torque regime', 'Car payload', 'CNW Index',
#        'Reader score', 'Sidewall height', 'Provenance', 'On board computer',
#        'Light in the trunk', 'Settings', 'Unit displacement', 'Trunk',
#        'USB connection', 'Urban', 'Radio'],
#       dtype='object')

# %%
df_object_columns = cleaned_data.select_dtypes(include=['object'])
df_object_columns
# Out:
#                         Fuel              Car size     Tuching  Propulsion  \
# 0                   Gasoline                Grande         NaN  Combustion
# 1                   Gasoline  Compact and portable  Mechanical  Combustion
# 2                   Gasoline                Medium       Hydro  Combustion
# 4                   Gasoline                Medium       Hydro  Combustion
# 5                   Gasoline                Medium       Hydro  Combustion
# ...                      ...                   ...         ...         ...
# 23881  Flex alcohol/gasoline  Compact and portable  Mechanical  Combustion
# 23882  Flex alcohol/gasoline  Compact and portable  Mechanical  Combustion
# 23890  Flex alcohol/gasoline  Compact and portable  Mechanical  Combustion
# 23902                 Diesel                Grande         NaN  Combustion
# 23903                 Diesel                Grande         NaN  Combustion
#
#       Car gearbox Provenance   Settings
# 0          Manual   Imported      Coupe
# 1          Manual   National  Hatchback
# 2          Manual   National  Hatchback
# 4          Manual   National  Hatchback
# 5          Manual   National  Hatchback
# ...           ...        ...        ...
# 23881   Automatic   National  Hatchback
# 23882   Automatic   National  Hatchback
# 23890   Automatic   National  Hatchback
# 23902      Manual   Imported        Van
# 23903      Manual   Imported        Van
#
# [20708 rows x 7 columns]

# %%
# # Define the file path to the 'Downloads' directory
# downloads_directory = os.path.expanduser('~/Downloads')

# # Specify the full file path for saving the CSV file
# csv_file_path = os.path.join(downloads_directory, 'df_8.csv')

# # Save the DataFrame to the CSV file
# df_object_columns.to_csv(csv_file_path, index=False)

# %% [markdown]
# ## we will impute Unknown in Nan values in categorical data

# %%
def impute_missing_with_unknown(df, columns):
    """
    Impute missing values with 'Unknown' in specified columns.

    Parameters:
    - df: pandas.DataFrame.
    - columns: List of column names where missing values should be imputed.

    Returns:
    - DataFrame with missing values in the specified columns replaced with 'Unknown'.
    """
    for col in columns:
        df[col] = df[col].fillna('Unknown')
    return df

# %%
columns=[['Tuching', 'Fuel']]

# %%
cleaned_data=impute_missing_with_unknown(cleaned_data, columns)
cleaned_data
# Out:
#        Carcode  Weight/Torque  Weight                   Fuel  Weight/power  \
# 0            1           24.9  1650.0               Gasoline          2.85
# 1            2           97.1   825.0               Gasoline         15.00
# 2            3           67.6  1170.0               Gasoline         10.09
# 4            5           59.9  1282.0               Gasoline          8.55
# 5            6           71.9  1200.0               Gasoline          9.09
# ...        ...            ...     ...                    ...           ...
# 23881    23884           63.4  1110.0  Flex alcohol/gasoline          9.25
# 23882    23885           63.4  1110.0  Flex alcohol/gasoline          9.25
# 23890    23893           63.4  1110.0  Flex alcohol/gasoline          9.25
# 23902    23905           63.2  2192.0                 Diesel         15.66
# 23903    23906           63.2  2192.0                 Diesel         15.66
#
#        Max power regime.  Cylinder diameter  Fuel tank  \
# 0                 7500.0               87.0      100.0
# 1                 5500.0               70.0       50.0
# 2                 5200.0               86.0       52.0
# 4                 5700.0               81.0       55.0
# 5                 6500.0               82.0       50.0
# ...                  ...                ...        ...
# 23881             6000.0               71.0       50.0
# 23882             6000.0               71.0       50.0
# 23890             6000.0               71.0       50.0
# 23902             3750.0               85.0       90.0
# 23903             3750.0               85.0       90.0
#
#        Steering wheel adjustment height  Specific power  ...  Sidewall height  \
# 0                                     0            93.5  ...            101.0
# 1                                     0            55.1  ...            116.0
# 2                                     0            58.1  ...            113.0
# 4                                     0            84.2  ...            123.0
# 5                                     0            75.6  ...            107.0
# ...                                 ...             ...  ...              ...
# 23881                                 0           120.2  ...            107.0
# 23882                                 1           120.2  ...            107.0
# 23890                                 1           120.2  ...            107.0
# 23902                                 0            64.2  ...            169.0
# 23903                                 0            64.2  ...            169.0
#
#        Provenance  On board computer  Light in the trunk   Settings  \
# 0        Imported                  0                   0      Coupe
# 1        National                  0                   0  Hatchback
# 2        National                  0                   0  Hatchback
# 4        National                  0                   0  Hatchback
# 5        National                  0                   0  Hatchback
# ...           ...                ...                 ...        ...
# 23881    National                  1                   0  Hatchback
# 23882    National                  1                   0  Hatchback
# 23890    National                  1                   1  Hatchback
# 23902    Imported                  1                   1        Van
# 23903    Imported                  1                   1        Van
#
#        Unit displacement    Trunk  USB connection  Urban  Radio
# 0                  516.0     50.0               0    2.4      0
# 1                  250.0    290.0               0   10.0      0
# 2                  500.0    370.0               0    7.2      0
# 4                  445.0    330.0               0    6.8      0
# 5                  437.0    370.0               0    9.0      0
# ...                  ...      ...             ...    ...    ...
# 23881              333.0    300.0               1    8.3      1
# 23882              333.0    300.0               1    8.3      1
# 23890              333.0    300.0               1    9.0      1
# 23902              545.0  11500.0               1   10.0      1
# 23903              545.0  13000.0               1   10.0      1
#
# [20708 rows x 67 columns]

# %%
nan_percentage_per_column = cleaned_data.isnull().mean() * 100

# Create a new DataFrame with column names and NaN percentages and Dtypes
nan_info_df = pd.DataFrame({
    'Column Name': nan_percentage_per_column.index,
    'NaN Percentage': nan_percentage_per_column.values,
    'Data Type': cleaned_data.dtypes
})

# Display the new DataFrame
nan_info_df[0:50] # Cheking 50 by 50 to see whole list at a time.
# Out:
#                                                                Column Name  \
# Carcode                                                            Carcode
# Weight/Torque                                                Weight/Torque
# Weight                                                              Weight
# Fuel                                                                  Fuel
# Weight/power                                                  Weight/power
# Max power regime.                                        Max power regime.
# Cylinder diameter                                        Cylinder diameter
# Fuel tank                                                        Fuel tank
# Steering wheel adjustment height          Steering wheel adjustment height
# Specific power                                              Specific power
# Multifunctional steering wheel              Multifunctional steering wheel
# Driver s seat with height adjustment  Driver s seat with height adjustment
# Alloy wheels                                                  Alloy wheels
# Maximum power                                                Maximum power
# Car size                                                          Car size
# Hot air                                                            Hot air
# Rear window                                                    Rear window
# Electric rearview mirror adjustment    Electric rearview mirror adjustment
# Air conditioning                                          Air conditioning
# Frontal Airbags                                            Frontal Airbags
# Electric front window control                Electric front window control
# Folding rear seat                                        Folding rear seat
# ABS brakes                                                      ABS brakes
# Central locking of the doors                  Central locking of the doors
# Perimeter anti theft alarm                      Perimeter anti theft alarm
# Bluetooth connection                                  Bluetooth connection
# Acceleration 0100 km/h in S                    Acceleration 0100 km/h in S
# Length                                                              Length
# Maximum torque                                              Maximum torque
# Width                                                                Width
# Rev counter                                                    Rev counter
# Compression ratio                                        Compression ratio
# Assisted direction                                      Assisted direction
# Tuching                                                            Tuching
# Guarantee in years                                      Guarantee in years
# Drag coefficient                                          Drag coefficient
# Height                                                              Height
# Specific torque                                            Specific torque
# Minimum height from the ground              Minimum height from the ground
# Propulsion                                                      Propulsion
# Piston course                                                Piston course
# Car gearbox                                                    Car gearbox
# Price R                                                            Price R
# Headrest for all occupants                      Headrest for all occupants
# Front gauge                                                    Front gauge
# Displacement                                                  Displacement
# Cooling liquid thermometer                      Cooling liquid thermometer
# Turns diameter                                              Turns diameter
# Rear gauge                                                      Rear gauge
# Length between the axis                            Length between the axis
#
#                                       NaN Percentage Data Type
# Carcode                                     0.000000     int64
# Weight/Torque                               0.000000   float64
# Weight                                      0.000000   float64
# Fuel                                        0.000000    object
# Weight/power                                0.000000   float64
# Max power regime.                           0.709871   float64
# Cylinder diameter                           1.028588   float64
# Fuel tank                                   0.709871   float64
# Steering wheel adjustment height            0.000000     int64
# Specific power                              0.709871   float64
# Multifunctional steering wheel              0.000000     int64
# Driver s seat with height adjustment        0.000000     int64
# Alloy wheels                                0.000000     int64
# Maximum power                               0.709871   float64
# Car size                                    0.000000    object
# Hot air                                     0.000000     int64
# Rear window                                 0.000000     int64
# Electric rearview mirror adjustment         0.000000     int64
# Air conditioning                            0.000000     int64
# Frontal Airbags                             0.000000     int64
# Electric front window control               0.000000     int64
# Folding rear seat                           0.000000     int64
# ABS brakes                                  0.000000     int64
# Central locking of the doors                0.000000     int64
# Perimeter anti theft alarm                  0.000000     int64
# Bluetooth connection                        0.000000     int64
# Acceleration 0100 km/h in S                17.046552   float64
# Length                                      0.000000   float64
# Maximum torque                              0.709871   float64
# Width                                       0.000000   float64
# Rev counter                                 0.000000     int64
# Compression ratio                           1.265212   float64
# Assisted direction                          0.000000     int64
# Tuching                                     0.000000    object
# Guarantee in years                          0.000000     int64
# Drag coefficient                           37.328569   float64
# Height                                      0.000000   float64
# Specific torque                             0.709871   float64
# Minimum height from the ground             45.484837   float64
# Propulsion                                  0.000000    object
# Piston course                               1.028588   float64
# Car gearbox                                 0.000000    object
# Price R                                     2.337261   float64
# Headrest for all occupants                  0.000000     int64
# Front gauge                                23.198764   float64
# Displacement                                0.709871   float64
# Cooling liquid thermometer                  0.000000     int64
# Turns diameter                             10.971605   float64
# Rear gauge                                 23.198764   float64
# Length between the axis                     0.000000   float64

# %% [markdown]
# ## Applying one hot encoding to categorical data.

# %%
# from sklearn.compose import ColumnTransformer
# from sklearn.preprocessing import OneHotEncoder
# import pandas as pd


# # Define the categorical columns you want to encode
# categorical_columns = ['Tuching', 'Propulsion', 'Car gearbox', 'Fuel', 'Provenance', 'Settings', 'Car size']  # Adjust as needed

# # Initialize the ColumnTransformer to apply OneHotEncoding to the categorical columns
# preprocessor = ColumnTransformer(
#     transformers=[
#         ('cat', OneHotEncoder(), categorical_columns)
#     ],
#     remainder='passthrough'  # Keep other columns unchanged
# )

# # Apply the transformations to the dataset
# # This will fit the OneHotEncoder to your categorical data and transform it,
# # while leaving the rest of your columns unchanged
# transformed_data = preprocessor.fit_transform(cleaned_data)

# # Get the new feature names for the one-hot encoded columns
# new_feature_names = preprocessor.named_transformers_['cat'].get_feature_names_out(categorical_columns)

# # Combine the new feature names with the names of the non-transformed columns
# final_feature_names = list(new_feature_names) + [col for col in cleaned_data.columns if col not in categorical_columns]

# # Create a new DataFrame with the transformed data and the correct column names
# final_df = pd.DataFrame(transformed_data, columns=final_feature_names)

# # Display the first few rows of the final DataFrame
# final_df.head()

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
import pandas as pd

def encode_categorical_columns(data, categorical_columns):
    """
    Applies one-hot encoding to specified categorical columns in a DataFrame.

    Parameters:
    - data: pandas.DataFrame, the DataFrame containing the data.
    - categorical_columns: list, a list of column names to be one-hot encoded.

    Returns:
    - A new DataFrame with the specified columns one-hot encoded and original columns unchanged.
    """
    # Initialize the ColumnTransformer
    preprocessor = ColumnTransformer(
        transformers=[
            ('cat', OneHotEncoder(), categorical_columns)
        ],
        remainder='passthrough'  # Keep other columns unchanged
    )


    # Apply the transformations to the dataset
    transformed_data = preprocessor.fit_transform(data)

    # Get the new feature names for the one-hot encoded columns
    new_feature_names = preprocessor.named_transformers_['cat'].get_feature_names_out(categorical_columns)

    # Combine the new feature names with the names of the non-transformed columns
    final_feature_names = [col for col in data.columns if col not in categorical_columns] + list(new_feature_names)

    # Create a new DataFrame with the transformed data and the correct column names
    final_df = pd.DataFrame(transformed_data, columns=final_feature_names, index=data.index)

    return final_df

# %%
# Select columns of dtype 'object'
df_object_columns = cleaned_data.select_dtypes(include=['object'])
# Define the categorical columns you want to encode
categorical_columns = ['Tuching', 'Propulsion', 'Car gearbox', 'Fuel', 'Provenance', 'Settings', 'Car size']

# %%
df_finale=encode_categorical_columns(df_object_columns, categorical_columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df_finale=encode_categorical_columns(df_object_columns, categorical_columns)
#
# Cell In[35], line 35, in encode_categorical_columns(data, categorical_columns)
#      32 final_feature_names = [col for col in data.columns if col not in categorical_columns] + list(new_feature_names)
#      34 # Create a new DataFrame with the transformed data and the correct column names
# ---> 35 final_df = pd.DataFrame(transformed_data, columns=final_feature_names, index=data.index)
#      37 return final_df
#
# File ~/.pyenv/versions/3.10.6/envs/car_recommendation_engine/lib/python3.10/site-packages/pandas/core/frame.py:856, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     848         mgr = arrays_to_mgr(
#     849             arrays,
#     850             columns,
#    (...)
#     853             typ=manager,
#     854         )
#     855     else:
# --> 856         mgr = ndarray_to_mgr(
#     857             data,
#     858             index,
#     859             columns,
#     860             dtype=dtype,
#     861             copy=copy,
#     862             typ=manager,
#     863         )
#     864 else:
#     865     mgr = dict_to_mgr(
#     866         {},
#     867         index,
#    (...)
#     870         typ=manager,
#     871     )
#
# File ~/.pyenv/versions/3.10.6/envs/car_recommendation_engine/lib/python3.10/site-packages/pandas/core/internals/construction.py:336, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     331 # _prep_ndarraylike ensures that values.ndim == 2 at this point
#     332 index, columns = _get_axes(
#     333     values.shape[0], values.shape[1], index=index, columns=columns
#     334 )
# --> 336 _check_values_indices_shape_match(values, index, columns)
#     338 if typ == "array":
#     339     if issubclass(values.dtype.type, str):
#
# File ~/.pyenv/versions/3.10.6/envs/car_recommendation_engine/lib/python3.10/site-packages/pandas/core/internals/construction.py:420, in _check_values_indices_shape_match(values, index, columns)
#     418 passed = values.shape
#     419 implied = (len(index), len(columns))
# --> 420 raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (20708, 1), indices imply (20708, 40)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
import pandas as pd

def encode_all_columns(data):
    """
    Applies one-hot encoding to all columns in a DataFrame, assuming all are categorical.
    Correctly handles the construction of the output DataFrame to avoid shape mismatches.

    Parameters:
    - data: pandas.DataFrame, the DataFrame containing only categorical data.

    Returns:
    - A DataFrame with all columns one-hot encoded.
    """
    # Initialize the OneHotEncoder
    encoder = OneHotEncoder()

    # Apply the transformations to the entire dataset
    transformed_data = encoder.fit_transform(data)

    # Get the new feature names for the one-hot encoded columns
    new_feature_names = encoder.get_feature_names_out(input_features=data.columns)

    # Correctly handle the shape of transformed_data when creating the new DataFrame
    # Ensure the number of columns in final_df matches the length of new_feature_names
    final_df = pd.DataFrame(transformed_data, columns=new_feature_names, index=data.index)

    return final_df

# %%
# Select columns of dtype 'object'
df_object_columns = cleaned_data.select_dtypes(include=['object'])

# %%
cat_df=encode_all_columns(df_object_columns)
cat_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 cat_df=encode_all_columns(df_object_columns)
#       2 cat_df
#
# Cell In[33], line 27, in encode_all_columns(data)
#      23 new_feature_names = encoder.get_feature_names_out(input_features=data.columns)
#      25 # Correctly handle the shape of transformed_data when creating the new DataFrame
#      26 # Ensure the number of columns in final_df matches the length of new_feature_names
# ---> 27 final_df = pd.DataFrame(transformed_data, columns=new_feature_names, index=data.index)
#      29 return final_df
#
# File ~/.pyenv/versions/3.10.6/envs/car_recommendation_engine/lib/python3.10/site-packages/pandas/core/frame.py:856, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     848         mgr = arrays_to_mgr(
#     849             arrays,
#     850             columns,
#    (...)
#     853             typ=manager,
#     854         )
#     855     else:
# --> 856         mgr = ndarray_to_mgr(
#     857             data,
#     858             index,
#     859             columns,
#     860             dtype=dtype,
#     861             copy=copy,
#     862             typ=manager,
#     863         )
#     864 else:
#     865     mgr = dict_to_mgr(
#     866         {},
#     867         index,
#    (...)
#     870         typ=manager,
#     871     )
#
# File ~/.pyenv/versions/3.10.6/envs/car_recommendation_engine/lib/python3.10/site-packages/pandas/core/internals/construction.py:336, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     331 # _prep_ndarraylike ensures that values.ndim == 2 at this point
#     332 index, columns = _get_axes(
#     333     values.shape[0], values.shape[1], index=index, columns=columns
#     334 )
# --> 336 _check_values_indices_shape_match(values, index, columns)
#     338 if typ == "array":
#     339     if issubclass(values.dtype.type, str):
#
# File ~/.pyenv/versions/3.10.6/envs/car_recommendation_engine/lib/python3.10/site-packages/pandas/core/internals/construction.py:420, in _check_values_indices_shape_match(values, index, columns)
#     418 passed = values.shape
#     419 implied = (len(index), len(columns))
# --> 420 raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (20708, 1), indices imply (20708, 40)

# %%
# Define the categorical columns you want to encode
categorical_columns = ['Tuching', 'Propulsion', 'Car gearbox', 'Fuel', 'Provenance', 'Settings', 'Car size']

# %%
# Select columns of dtype 'object'
df_object_columns = cleaned_data.select_dtypes(include=['object'])

# Get just the column names
object_column_names = df_object_columns.columns.tolist()

# Display the column names
print(object_column_names)
# Out:
# ['Fuel', 'Car size', 'Tuching', 'Propulsion', 'Car gearbox', 'Provenance', 'Settings']

# %%
final_df=encode_categorical_columns(cleaned_data, categorical_columns)
final_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 final_df=encode_categorical_columns(cleaned_data, categorical_columns)
#       2 final_df
#
# Cell In[23], line 35, in encode_categorical_columns(data, categorical_columns)
#      32 final_feature_names = [col for col in data.columns if col not in categorical_columns] + list(new_feature_names)
#      34 # Create a new DataFrame with the transformed data and the correct column names
# ---> 35 final_df = pd.DataFrame(transformed_data, columns=final_feature_names, index=data.index)
#      37 return final_df
#
# File ~/.pyenv/versions/3.10.6/envs/car_recommendation_engine/lib/python3.10/site-packages/pandas/core/frame.py:856, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     848         mgr = arrays_to_mgr(
#     849             arrays,
#     850             columns,
#    (...)
#     853             typ=manager,
#     854         )
#     855     else:
# --> 856         mgr = ndarray_to_mgr(
#     857             data,
#     858             index,
#     859             columns,
#     860             dtype=dtype,
#     861             copy=copy,
#     862             typ=manager,
#     863         )
#     864 else:
#     865     mgr = dict_to_mgr(
#     866         {},
#     867         index,
#    (...)
#     870         typ=manager,
#     871     )
#
# File ~/.pyenv/versions/3.10.6/envs/car_recommendation_engine/lib/python3.10/site-packages/pandas/core/internals/construction.py:336, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     331 # _prep_ndarraylike ensures that values.ndim == 2 at this point
#     332 index, columns = _get_axes(
#     333     values.shape[0], values.shape[1], index=index, columns=columns
#     334 )
# --> 336 _check_values_indices_shape_match(values, index, columns)
#     338 if typ == "array":
#     339     if issubclass(values.dtype.type, str):
#
# File ~/.pyenv/versions/3.10.6/envs/car_recommendation_engine/lib/python3.10/site-packages/pandas/core/internals/construction.py:420, in _check_values_indices_shape_match(values, index, columns)
#     418 passed = values.shape
#     419 implied = (len(index), len(columns))
# --> 420 raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (20708, 1), indices imply (20708, 100)

# %%
# Define the file path to the 'Downloads' directory
downloads_directory = os.path.expanduser('~/Downloads')

# Specify the full file path for saving the CSV file
csv_file_path = os.path.join(downloads_directory, 'df_9.csv')

# Save the DataFrame to the CSV file
final_df.to_csv(csv_file_path, index=False)

# %%
nan_percentage_per_column = final_df.isnull().mean() * 100

# Create a new DataFrame with column names and NaN percentages and Dtypes
nan_info_df = pd.DataFrame({
    'Column Name': nan_percentage_per_column.index,
    'NaN Percentage': nan_percentage_per_column.values,
    'Data Type': final_df.dtypes
})

# Display the new DataFrame
nan_info_df[0:50] # Cheking 50 by 50 to see whole list at a time.
# Out:
#                                                        Column Name  \
# Tuching_Hydro                                        Tuching_Hydro
# Tuching_Mechanical                              Tuching_Mechanical
# Tuching_Unknown                                    Tuching_Unknown
# Propulsion_Combustion                        Propulsion_Combustion
# Propulsion_Electric                            Propulsion_Electric
# Propulsion_Hybrid                                Propulsion_Hybrid
# Propulsion_Light Hybrid                    Propulsion_Light Hybrid
# Propulsion_Plug-in hybrid                Propulsion_Plug-in hybrid
# Car gearbox_Automated                        Car gearbox_Automated
# Car gearbox_Automatic                        Car gearbox_Automatic
# Car gearbox_CVT                                    Car gearbox_CVT
# Car gearbox_Manual                              Car gearbox_Manual
# Fuel_Alcohol                                          Fuel_Alcohol
# Fuel_Diesel                                            Fuel_Diesel
# Fuel_Electricity                                  Fuel_Electricity
# Fuel_Electricity/gasoline                Fuel_Electricity/gasoline
# Fuel_Flex                                                Fuel_Flex
# Fuel_Flex alcohol/gasoline              Fuel_Flex alcohol/gasoline
# Fuel_Gasoline                                        Fuel_Gasoline
# Fuel_Unknown                                          Fuel_Unknown
# Provenance_Imported                            Provenance_Imported
# Provenance_National                            Provenance_National
# Settings_Chassicabine                        Settings_Chassicabine
# Settings_Convertible                          Settings_Convertible
# Settings_Coupe                                      Settings_Coupe
# Settings_Dune buggy                            Settings_Dune buggy
# Settings_Hatchback                              Settings_Hatchback
# Settings_Mini SUV                                Settings_Mini SUV
# Settings_Minivan                             Settings_Minivan
# Settings_Pickup truck                        Settings_Pickup truck
# Settings_SUV                                          Settings_SUV
# Settings_Sedan                                      Settings_Sedan
# Settings_Turkey, hen                          Settings_Turkey, hen
# Settings_Van                                          Settings_Van
# Car size_Compact and portable        Car size_Compact and portable
# Car size_Coupe                                      Car size_Coupe
# Car size_Grande                                    Car size_Grande
# Car size_Medium                                    Car size_Medium
# Car size_Medium Compact                    Car size_Medium Compact
# Car size_Subcompact                            Car size_Subcompact
# Carcode                                                    Carcode
# Weight/Torque                                        Weight/Torque
# Weight                                                      Weight
# Weight/power                                          Weight/power
# Max power regime.                                Max power regime.
# Cylinder diameter                                Cylinder diameter
# Fuel tank                                                Fuel tank
# Steering wheel adjustment height  Steering wheel adjustment height
# Specific power                                      Specific power
# Multifunctional steering wheel      Multifunctional steering wheel
#
#                                   NaN Percentage Data Type
# Tuching_Hydro                           0.000000   float64
# Tuching_Mechanical                      0.000000   float64
# Tuching_Unknown                         0.000000   float64
# Propulsion_Combustion                   0.000000   float64
# Propulsion_Electric                     0.000000   float64
# Propulsion_Hybrid                       0.000000   float64
# Propulsion_Light Hybrid                 0.000000   float64
# Propulsion_Plug-in hybrid               0.000000   float64
# Car gearbox_Automated                   0.000000   float64
# Car gearbox_Automatic                   0.000000   float64
# Car gearbox_CVT                         0.000000   float64
# Car gearbox_Manual                      0.000000   float64
# Fuel_Alcohol                            0.000000   float64
# Fuel_Diesel                             0.000000   float64
# Fuel_Electricity                        0.000000   float64
# Fuel_Electricity/gasoline               0.000000   float64
# Fuel_Flex                               0.000000   float64
# Fuel_Flex alcohol/gasoline              0.000000   float64
# Fuel_Gasoline                           0.000000   float64
# Fuel_Unknown                            0.000000   float64
# Provenance_Imported                     0.000000   float64
# Provenance_National                     0.000000   float64
# Settings_Chassicabine                   0.000000   float64
# Settings_Convertible                    0.000000   float64
# Settings_Coupe                          0.000000   float64
# Settings_Dune buggy                     0.000000   float64
# Settings_Hatchback                      0.000000   float64
# Settings_Mini SUV                       0.000000   float64
# Settings_Minivan                        0.000000   float64
# Settings_Pickup truck                   0.000000   float64
# Settings_SUV                            0.000000   float64
# Settings_Sedan                          0.000000   float64
# Settings_Turkey, hen                    0.000000   float64
# Settings_Van                            0.000000   float64
# Car size_Compact and portable           0.000000   float64
# Car size_Coupe                          0.000000   float64
# Car size_Grande                         0.000000   float64
# Car size_Medium                         0.000000   float64
# Car size_Medium Compact                 0.000000   float64
# Car size_Subcompact                     0.000000   float64
# Carcode                                 0.000000   float64
# Weight/Torque                           0.000000   float64
# Weight                                  0.000000   float64
# Weight/power                            0.000000   float64
# Max power regime.                       0.709871   float64
# Cylinder diameter                       1.028588   float64
# Fuel tank                               0.709871   float64
# Steering wheel adjustment height        0.000000   float64
# Specific power                          0.709871   float64
# Multifunctional steering wheel          0.000000   float64

# %% [markdown]
# ## putting 0 for empty cells in numerical columns.

# %%
def fill_missing_values_with_zero(data):
    """
    Fills all missing values in the DataFrame with 0.

    Parameters:
    - data: pandas.DataFrame, the DataFrame containing the data.

    Returns:
    - A new DataFrame with missing values filled with 0.
    """
    # Fill missing values with 0
    filled_data = data.fillna(0)

    return filled_data

# %%
final_cleaned_data=fill_missing_values_with_zero(final_df)

# %%
nan_percentage_per_column = final_cleaned_data.isnull().mean() * 100

# Create a new DataFrame with column names and NaN percentages and Dtypes
nan_info_df = pd.DataFrame({
    'Column Name': nan_percentage_per_column.index,
    'NaN Percentage': nan_percentage_per_column.values,
    'Data Type': final_cleaned_data.dtypes
})

# Display the new DataFrame
nan_info_df[0:50] # Cheking 50 by 50 to see whole list at a time.
# Out:
#                                                  Column Name  NaN Percentage  \
# Tuching_Hydro                                  Tuching_Hydro             0.0
# Tuching_Mechanical                        Tuching_Mechanical             0.0
# Tuching_Unknown                              Tuching_Unknown             0.0
# Propulsion_Combustion                  Propulsion_Combustion             0.0
# Propulsion_Electric                      Propulsion_Electric             0.0
# Propulsion_Hybrid                          Propulsion_Hybrid             0.0
# Propulsion_Light Hybrid              Propulsion_Light Hybrid             0.0
# Propulsion_Plug-in hybrid          Propulsion_Plug-in hybrid             0.0
# Car gearbox_Automated                  Car gearbox_Automated             0.0
# Car gearbox_Automatic                  Car gearbox_Automatic             0.0
# Car gearbox_CVT                              Car gearbox_CVT             0.0
# Car gearbox_Manual                        Car gearbox_Manual             0.0
# Fuel_Alcohol                                    Fuel_Alcohol             0.0
# Fuel_Diesel                                      Fuel_Diesel             0.0
# Fuel_Electricity                            Fuel_Electricity             0.0
# Fuel_Electricity/gasoline          Fuel_Electricity/gasoline             0.0
# Fuel_Flex                                          Fuel_Flex             0.0
# Fuel_Flex alcohol/gasoline        Fuel_Flex alcohol/gasoline             0.0
# Fuel_Gasoline                                  Fuel_Gasoline             0.0
# Fuel_Unknown                                    Fuel_Unknown             0.0
# Provenance_Imported                      Provenance_Imported             0.0
# Provenance_National                      Provenance_National             0.0
# Settings_Chassicabine                  Settings_Chassicabine             0.0
# Settings_Convertible                    Settings_Convertible             0.0
# Settings_Coupe                                Settings_Coupe             0.0
# Settings_Dune buggy                      Settings_Dune buggy             0.0
# Settings_Hatchback                        Settings_Hatchback             0.0
# Settings_Mini SUV                          Settings_Mini SUV             0.0
# Settings_Minivan                       Settings_Minivan                  0.0
# Settings_Pickup truck                  Settings_Pickup truck             0.0
# Settings_SUV                                    Settings_SUV             0.0
# Settings_Sedan                                Settings_Sedan             0.0
# Settings_Turkey, hen                    Settings_Turkey, hen             0.0
# Settings_Van                                    Settings_Van             0.0
# Car size_Compact and portable  Car size_Compact and portable             0.0
# Car size_Coupe                                Car size_Coupe             0.0
# Car size_Grande                              Car size_Grande             0.0
# Car size_Medium                              Car size_Medium             0.0
# Car size_Medium Compact              Car size_Medium Compact             0.0
# Car size_Subcompact                      Car size_Subcompact             0.0
# Hot air                                              Hot air             0.0
# Acceleration 0100 km/h in S      Acceleration 0100 km/h in S             0.0
# Length                                                Length             0.0
# Maximum torque                                Maximum torque             0.0
# Width                                                  Width             0.0
# Rev counter                                      Rev counter             0.0
# Compression ratio                          Compression ratio             0.0
# Assisted direction                        Assisted direction             0.0
# CNW Ranking                                      CNW Ranking             0.0
# ABS brakes                                        ABS brakes             0.0
#
#                               Data Type
# Tuching_Hydro                   float64
# Tuching_Mechanical              float64
# Tuching_Unknown                 float64
# Propulsion_Combustion           float64
# Propulsion_Electric             float64
# Propulsion_Hybrid               float64
# Propulsion_Light Hybrid         float64
# Propulsion_Plug-in hybrid       float64
# Car gearbox_Automated           float64
# Car gearbox_Automatic           float64
# Car gearbox_CVT                 float64
# Car gearbox_Manual              float64
# Fuel_Alcohol                    float64
# Fuel_Diesel                     float64
# Fuel_Electricity                float64
# Fuel_Electricity/gasoline       float64
# Fuel_Flex                       float64
# Fuel_Flex alcohol/gasoline      float64
# Fuel_Gasoline                   float64
# Fuel_Unknown                    float64
# Provenance_Imported             float64
# Provenance_National             float64
# Settings_Chassicabine           float64
# Settings_Convertible            float64
# Settings_Coupe                  float64
# Settings_Dune buggy             float64
# Settings_Hatchback              float64
# Settings_Mini SUV               float64
# Settings_Minivan                float64
# Settings_Pickup truck           float64
# Settings_SUV                    float64
# Settings_Sedan                  float64
# Settings_Turkey, hen            float64
# Settings_Van                    float64
# Car size_Compact and portable   float64
# Car size_Coupe                  float64
# Car size_Grande                 float64
# Car size_Medium                 float64
# Car size_Medium Compact         float64
# Car size_Subcompact             float64
# Hot air                         float64
# Acceleration 0100 km/h in S     float64
# Length                          float64
# Maximum torque                  float64
# Width                           float64
# Rev counter                     float64
# Compression ratio               float64
# Assisted direction              float64
# CNW Ranking                     float64
# ABS brakes                      float64

# %%
# Define the file path to the 'Downloads' directory
downloads_directory = os.path.expanduser('~/Downloads')

# Specify the full file path for saving the CSV file
csv_file_path = os.path.join(downloads_directory, 'df_9.csv')

# Save the DataFrame to the CSV file
final_df.to_csv(csv_file_path, index=False)

# %%
import pandas as pd
# Out:
# /var/folders/ld/s5_rrf_n32q9rltztl0sz_fh0000gn/T/ipykernel_67576/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
features_df=pd.read_csv('/Users/bididudy/code/marcnaweb/car_recommendation_engine/raw_data/categorized_car_features.csv')
# Out:
# /var/folders/ld/s5_rrf_n32q9rltztl0sz_fh0000gn/T/ipykernel_67576/1563681195.py:1: DtypeWarning: Columns (35,43,54,76,77,78,79,84,85,86,87,88,89,90,91,93,94,95,96,98,99,100,101,118,119,139,145,146,154,157,175,180,189,197,204,214,235,239,241,249,263,269,280,281) have mixed types. Specify dtype option on import or set low_memory=False.
#   features_df=pd.read_csv('/Users/bididudy/code/marcnaweb/car_recommendation_engine/raw_data/categorized_car_features.csv')

# %%
features_df.rename(columns={'Carcode': 'car_code'}, inplace=True)

# %%
prices_relevant_df=pd.read_csv('/Users/bididudy/code/marcnaweb/car_recommendation_engine/raw_data/car_prices_enriched_v3_carPriceIndex.csv')

# %%
last_price_df=prices_relevant_df[['car_code', 'car_last_price_in_brl']]

# %%
import pandas as pd

# Assuming you've already loaded the datasets into features_df and prices_df

# Step 1: Define the matching columns. Replace these with actual matching columns.
matching_columns = ['car_code']

# Step 2: Merge the datasets based on the defined matching columns.
# Note: This step assumes that both datasets contain the columns defined in `matching_columns`.
# You might need to adjust the columns in each dataset to match exactly.
merged_df = pd.merge(features_df, last_price_df, how='left', on='car_code')

# Step 3: Check the merged dataset
merged_df.columns
# Out:
# Index(['car_code', 'Deactivation of cylinders',
#        'Frontal Driver Seat Extension', 'Driver s seat with memories', 'Power',
#        'Weight/Torque', 'Driver s seat with heating',
#        'Driver s seat with electrical adjustment', 'Weight',
#        'Lumbar Support Adjustment for the Driver',
#        ...
#        'Headlights with height adjustment', 'Platform', 'Urban autonomyG',
#        'Pneumatic suspension', 'Radio', 'Maximum speed electric mode',
#        'Electronic noise cancellation', 'Facial recognition camera',
#        'Track centralization assistant', 'car_last_price_in_brl'],
#       dtype='object', length=283)

# %%
import os

# Define the file path to the 'Downloads' directory
downloads_directory = os.path.expanduser('~/Downloads')

# Specify the full file path for saving the CSV file
csv_file_path = os.path.join(downloads_directory, 'df_9.csv')

# Save the DataFrame to the CSV file
merged_df.to_csv(csv_file_path, index=False)

# %%
filtered_columns = merged_df.columns[merged_df.isna().sum() < 15000]
filtered_df = merged_df[filtered_columns]

# %%
filtered_df .shape
# Out:
# (23904, 93)
