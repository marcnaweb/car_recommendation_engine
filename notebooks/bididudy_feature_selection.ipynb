# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/Users/bididudy/code/marcnaweb/car_recommendation_engine/raw_data/categorized_car_features.csv')
df.head()
# Out:
# /var/folders/ld/s5_rrf_n32q9rltztl0sz_fh0000gn/T/ipykernel_56395/3140573242.py:4: DtypeWarning: Columns (35,43,54,76,77,78,79,84,85,86,87,88,89,90,91,93,94,95,96,98,99,100,101,118,119,139,145,146,154,157,175,180,189,197,204,214,235,239,241,249,263,269,280,281) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/bididudy/code/marcnaweb/car_recommendation_engine/raw_data/categorized_car_features.csv')
#    Carcode Deactivation of cylinders Frontal Driver Seat Extension  \
# 0        1                       NaN                           NaN
# 1        2                       NaN                           NaN
# 2        3                       NaN                           NaN
# 3        4                       NaN                           NaN
# 4        5                       NaN                           NaN
#
#   Driver s seat with memories Power Weight/Torque Driver s seat with heating  \
# 0                         NaN   NaN  24,9 kg/kgfm                        NaN
# 1                         NaN   NaN  97,1 kg/kgfm                        NaN
# 2                         NaN   NaN  67,6 kg/kgfm                        NaN
# 3                         NaN   NaN           NaN                        NaN
# 4                         NaN   NaN  59,9 kg/kgfm                        NaN
#
#   Driver s seat with electrical adjustment   Weight  \
# 0                                      NaN  1650 kg
# 1                                      NaN   825 kg
# 2                                      NaN  1170 kg
# 3                                      NaN      NaN
# 4                                      NaN  1282 kg
#
#   Lumbar Support Adjustment for the Driver  ... Tire Pressure Monitoring  \
# 0                                      NaN  ...                      NaN
# 1                                      NaN  ...                      NaN
# 2                                      NaN  ...                      NaN
# 3                                      NaN  ...                      NaN
# 4                                      NaN  ...                      NaN
#
#   Headlights with height adjustment Platform Urban autonomyG  \
# 0                               NaN      NaN             NaN
# 1                               NaN      NaN             NaN
# 2                               NaN    Tbody             NaN
# 3                               NaN      NaN             NaN
# 4                               NaN     PQ34             NaN
#
#   Pneumatic suspension Radio Maximum speed electric mode  \
# 0                  NaN   NaN                         NaN
# 1                  NaN   NaN                         NaN
# 2                  NaN   NaN                         NaN
# 3                  NaN   NaN                         NaN
# 4                  NaN   NaN                         NaN
#
#   Electronic noise cancellation Facial recognition camera  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
#
#   Track centralization assistant
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
# [5 rows x 282 columns]

# %%
df.columns
# Out:
# Index(['Carcode', 'Deactivation of cylinders', 'Frontal Driver Seat Extension',
#        'Driver s seat with memories', 'Power', 'Weight/Torque',
#        'Driver s seat with heating',
#        'Driver s seat with electrical adjustment', 'Weight',
#        'Lumbar Support Adjustment for the Driver',
#        ...
#        'Tire Pressure Monitoring', 'Headlights with height adjustment',
#        'Platform', 'Urban autonomyG', 'Pneumatic suspension', 'Radio',
#        'Maximum speed electric mode', 'Electronic noise cancellation',
#        'Facial recognition camera', 'Track centralization assistant'],
#       dtype='object', length=282)

# %%
df['Ipva R'].isnull().sum()
# Out:
# 8922

# %%
filtered_columns = df.columns[df.isna().sum() < 15000]
filtered_df = df[filtered_columns]
filtered_df.head()
# Out:
#    Carcode Weight/Torque   Weight      Fuel Weight/power Max power regime.  \
# 0        1  24,9 kg/kgfm  1650 kg  Gasoline   2,85 kg/cv          7500 rpm
# 1        2  97,1 kg/kgfm   825 kg  Gasoline  15,00 kg/cv          5500 rpm
# 2        3  67,6 kg/kgfm  1170 kg  Gasoline  10,09 kg/cv          5200 rpm
# 3        4           NaN      NaN       NaN          NaN               NaN
# 4        5  59,9 kg/kgfm  1282 kg  Gasoline   8,55 kg/cv          5700 rpm
#
#   Cylinder diameter  Cylinders Engine code   Fuel tank  ...  \
# 0             87 mm    12 in V         NaN  100 litros  ...
# 1             70 mm  LINE-UP 4        Fire   50 litros  ...
# 2             86 mm  LINE-UP 4  Família II   52 litros  ...
# 3               NaN        NaN         NaN         NaN  ...
# 4             81 mm  LINE-UP 4       EA113   55 litros  ...
#
#   Light in the trunk   Settings Unit displacement       Trunk  \
# 0                NaN      Coupe          516 cm^3   50 litros
# 1                NaN  Hatchback          250 cm^3  290 litros
# 2                NaN  Hatchback          500 cm^3  370 litros
# 3                NaN        NaN               NaN         NaN
# 4                NaN  Hatchback          445 cm^3  330 litros
#
#   Gear change code USB connection Corrected frontal area     Urban Platform  \
# 0              NaN            NaN              0,650 m^2  2,4 km/l      NaN
# 1             C513            NaN              0,684 m^2   10 km/l      NaN
# 2          F175 CR            NaN              0,624 m^2  7,2 km/l    Tbody
# 3              NaN            NaN                    NaN       NaN      NaN
# 4              NaN            NaN              0,651 m^2  6,8 km/l     PQ34
#
#   Radio
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
#
# [5 rows x 92 columns]

# %%
test_filtered_df =filtered_df.dropna(subset='Acceleration')
test_filtered_df
# Out:
#        Carcode Weight/Torque   Weight                   Fuel Weight/power  \
# 0            1  24,9 kg/kgfm  1650 kg               Gasoline   2,85 kg/cv
# 1            2  97,1 kg/kgfm   825 kg               Gasoline  15,00 kg/cv
# 2            3  67,6 kg/kgfm  1170 kg               Gasoline  10,09 kg/cv
# 4            5  59,9 kg/kgfm  1282 kg               Gasoline   8,55 kg/cv
# 5            6  71,9 kg/kgfm  1200 kg               Gasoline   9,09 kg/cv
# ...        ...           ...      ...                    ...          ...
# 23881    23884  63,4 kg/kgfm  1110 kg  Flex alcohol/gasoline   9,25 kg/cv
# 23882    23885  63,4 kg/kgfm  1110 kg  Flex alcohol/gasoline   9,25 kg/cv
# 23890    23893  63,4 kg/kgfm  1110 kg  Flex alcohol/gasoline   9,25 kg/cv
# 23902    23905  63,2 kg/kgfm  2192 kg                 Diesel  15,66 kg/cv
# 23903    23906  63,2 kg/kgfm  2192 kg                 Diesel  15,66 kg/cv
#
#       Max power regime. Cylinder diameter  Cylinders Engine code   Fuel tank  \
# 0              7500 rpm             87 mm    12 in V         NaN  100 litros
# 1              5500 rpm             70 mm  LINE-UP 4        Fire   50 litros
# 2              5200 rpm             86 mm  LINE-UP 4  Família II   52 litros
# 4              5700 rpm             81 mm  LINE-UP 4       EA113   55 litros
# 5              6500 rpm             82 mm  LINE-UP 4         VFD   50 litros
# ...                 ...               ...        ...         ...         ...
# 23881          6000 rpm             71 mm  3 in line       Kappa   50 litros
# 23882          6000 rpm             71 mm  3 in line       Kappa   50 litros
# 23890          6000 rpm             71 mm  3 in line       Kappa   50 litros
# 23902          3750 rpm             85 mm  LINE-UP 4        DW12   90 litros
# 23903          3750 rpm             85 mm  LINE-UP 4        DW12   90 litros
#
#        ...  Light in the trunk   Settings Unit displacement         Trunk  \
# 0      ...                 NaN      Coupe          516 cm^3     50 litros
# 1      ...                 NaN  Hatchback          250 cm^3    290 litros
# 2      ...                 NaN  Hatchback          500 cm^3    370 litros
# 4      ...                 NaN  Hatchback          445 cm^3    330 litros
# 5      ...                 NaN  Hatchback          437 cm^3    370 litros
# ...    ...                 ...        ...               ...           ...
# 23881  ...                 NaN  Hatchback          333 cm^3    300 litros
# 23882  ...                 NaN  Hatchback          333 cm^3    300 litros
# 23890  ...  Standard equipment  Hatchback          333 cm^3    300 litros
# 23902  ...  Standard equipment        Van          545 cm^3  11500 litros
# 23903  ...  Standard equipment        Van          545 cm^3  13000 litros
#
#       Gear change code      USB connection Corrected frontal area       Urban  \
# 0                  NaN                 NaN              0,650 m^2    2,4 km/l
# 1                 C513                 NaN              0,684 m^2     10 km/l
# 2              F175 CR                 NaN              0,624 m^2    7,2 km/l
# 4                  NaN                 NaN              0,651 m^2    6,8 km/l
# 5                 C510                 NaN                    NaN      9 km/l
# ...                ...                 ...                    ...         ...
# 23881              NaN  Standard equipment                    NaN  8,3 km/l A
# 23882              NaN  Standard equipment                    NaN  8,3 km/l A
# 23890              NaN  Standard equipment                    NaN    9 km/l A
# 23902             ML6C  Standard equipment                    NaN     10 km/l
# 23903             ML6C  Standard equipment                    NaN     10 km/l
#
#       Platform               Radio
# 0          NaN                 NaN
# 1          NaN                 NaN
# 2        Tbody                 NaN
# 4         PQ34                 NaN
# 5          NaN                 NaN
# ...        ...                 ...
# 23881       PB  Standard equipment
# 23882       PB  Standard equipment
# 23890       PB  Standard equipment
# 23902      NaN  Optional equipment
# 23903      NaN  Optional equipment
#
# [20708 rows x 92 columns]

# %%
nan_percentage_per_column = test_filtered_df.isnull().mean() * 100

# Create a new DataFrame with column names and NaN percentages and Dtypes
nan_info_df = pd.DataFrame({
    'Column Name': nan_percentage_per_column.index,
    'NaN Percentage': nan_percentage_per_column.values,
    'Data Type': test_filtered_df.dtypes
})

# Display the new DataFrame
nan_info_df[0:50] # Cheking 50 by 50 to see whole list at a time.
# Out:
#                                                                Column Name  \
# Carcode                                                            Carcode
# Weight/Torque                                                Weight/Torque
# Weight                                                              Weight
# Fuel                                                                  Fuel
# Weight/power                                                  Weight/power
# Max power regime.                                        Max power regime.
# Cylinder diameter                                        Cylinder diameter
# Cylinders                                                        Cylinders
# Engine code                                                    Engine code
# Fuel tank                                                        Fuel tank
# Steering wheel adjustment height          Steering wheel adjustment height
# Specific power                                              Specific power
# Multifunctional steering wheel              Multifunctional steering wheel
# Engine power supply                                    Engine power supply
# Driver s seat with height adjustment  Driver s seat with height adjustment
# Engine control activation                        Engine control activation
# Alloy wheels                                                  Alloy wheels
# Maximum power                                                Maximum power
# Car size                                                          Car size
# Hot air                                                            Hot air
# Rear window                                                    Rear window
# Electric rearview mirror adjustment    Electric rearview mirror adjustment
# Air conditioning                                          Air conditioning
# Frontal Airbags                                            Frontal Airbags
# Electric front window control                Electric front window control
# Folding rear seat                                        Folding rear seat
# ABS brakes                                                      ABS brakes
# Central locking of the doors                  Central locking of the doors
# Perimeter anti theft alarm                      Perimeter anti theft alarm
# Bluetooth connection                                  Bluetooth connection
# Acceleration                                                  Acceleration
# Length                                                              Length
# Maximum torque                                              Maximum torque
# Assistance                                                      Assistance
# Width                                                                Width
# Rev counter                                                    Rev counter
# Compression ratio                                        Compression ratio
# Assisted direction                                      Assisted direction
# Tuching                                                            Tuching
# Guarantee                                                        Guarantee
# Drag coefficient                                          Drag coefficient
# Height                                                              Height
# Specific torque                                            Specific torque
# Aspiration                                                      Aspiration
# Minimum height from the ground              Minimum height from the ground
# Propulsion                                                      Propulsion
# Piston course                                                Piston course
# Rear tires                                                      Rear tires
# Urban autonomy                                              Urban autonomy
# Car gearbox                                                    Car gearbox
#
#                                       NaN Percentage Data Type
# Carcode                                     0.000000     int64
# Weight/Torque                               0.000000    object
# Weight                                      0.000000    object
# Fuel                                        0.985127    object
# Weight/power                                0.000000    object
# Max power regime.                           0.709871    object
# Cylinder diameter                           1.028588    object
# Cylinders                                   0.714700    object
# Engine code                                11.536604    object
# Fuel tank                                   0.709871    object
# Steering wheel adjustment height           50.251111    object
# Specific power                              0.709871    object
# Multifunctional steering wheel             56.041144    object
# Engine power supply                         0.709871    object
# Driver s seat with height adjustment       50.555341    object
# Engine control activation                  18.785011    object
# Alloy wheels                               53.810122    object
# Maximum power                               0.709871    object
# Car size                                    0.000000    object
# Hot air                                    46.233340    object
# Rear window                                49.666795    object
# Electric rearview mirror adjustment        51.332818    object
# Air conditioning                           46.407186    object
# Frontal Airbags                            47.561329    object
# Electric front window control              47.310218    object
# Folding rear seat                          52.796021    object
# ABS brakes                                 48.333977    object
# Central locking of the doors               47.310218    object
# Perimeter anti theft alarm                 56.475758    object
# Bluetooth connection                       56.326058    object
# Acceleration                                0.000000    object
# Length                                      0.000000    object
# Maximum torque                              0.709871    object
# Assistance                                  0.053120    object
# Width                                       0.000000    object
# Rev counter                                47.711030    object
# Compression ratio                           0.922349    object
# Assisted direction                         46.440989    object
# Tuching                                    42.080355    object
# Guarantee                                   0.000000    object
# Drag coefficient                           37.328569    object
# Height                                      0.000000    object
# Specific torque                             0.709871    object
# Aspiration                                  0.709871    object
# Minimum height from the ground             45.484837    object
# Propulsion                                  0.000000    object
# Piston course                               1.028588    object
# Rear tires                                  0.000000    object
# Urban autonomy                              0.709871    object
# Car gearbox                                 0.000000    object

# %%
column_to_remove = ['Assistance','Aspiration', 'Rear tires', 'Spare tire', 'Front tires',
                    'Urban autonomy', 'Generation', 'Front suspension', 'Rear suspension', 'Coupling', 'Valve command',
                     'Disposition', 'Cylinders', 'Elastic element', 'Ipva R', 'Frontal area A', 'Engine code',
                    'Traction', 'Installation', 'Road autonomy', 'Engine power supply', 'Engine control activation',
                    'Gear change code', 'Corrected frontal area', 'Platform']

# test_filtered_df['check feature name here'].unique() # check feature

# %%
new_filtered_df = test_filtered_df.drop(columns=column_to_remove)
new_filtered_df.head(3)
# Out:
#    Carcode Weight/Torque   Weight      Fuel Weight/power Max power regime.  \
# 0        1  24,9 kg/kgfm  1650 kg  Gasoline   2,85 kg/cv          7500 rpm
# 1        2  97,1 kg/kgfm   825 kg  Gasoline  15,00 kg/cv          5500 rpm
# 2        3  67,6 kg/kgfm  1170 kg  Gasoline  10,09 kg/cv          5200 rpm
#
#   Cylinder diameter   Fuel tank Steering wheel adjustment height  \
# 0             87 mm  100 litros                              NaN
# 1             70 mm   50 litros                              NaN
# 2             86 mm   52 litros                              NaN
#
#   Specific power  ... Sidewall height Provenance On board computer  \
# 0  93,5 cv/litro  ...          101 mm   Imported               NaN
# 1  55,1 cv/litro  ...          116 mm   National               NaN
# 2  58,1 cv/litro  ...          113 mm   National               NaN
#
#   Light in the trunk   Settings Unit displacement       Trunk USB connection  \
# 0                NaN      Coupe          516 cm^3   50 litros            NaN
# 1                NaN  Hatchback          250 cm^3  290 litros            NaN
# 2                NaN  Hatchback          500 cm^3  370 litros            NaN
#
#       Urban Radio
# 0  2,4 km/l   NaN
# 1   10 km/l   NaN
# 2  7,2 km/l   NaN
#
# [3 rows x 67 columns]

# %%
preprocessing_df = new_filtered_df.copy()

columns_to_transform = ['Hot air', 'Rev counter', 'Assisted direction', 'ABS brakes', 'Rear window', 'Central locking of the doors',
                        'Headrest for all occupants', 'Electric rearview mirror adjustment', 'Air conditioning',
                        'Bluetooth connection', 'Frontal Airbags', 'Steering wheel adjustment height',
                        'Electric front window control', 'Multifunctional steering wheel', 'Driver s seat with height adjustment',
                        'On board computer', 'Light in the trunk', 'Alloy wheels', 'USB connection', 'Radio',
                        'Folding rear seat', 'Perimeter anti theft alarm', 'Cooling liquid thermometer']

# Replace NaN with 0 and other values with 1
preprocessing_df[columns_to_transform] = preprocessing_df[columns_to_transform].applymap(lambda x: 0 if pd.isnull(x) else 1)
# Out:
# /var/folders/ld/s5_rrf_n32q9rltztl0sz_fh0000gn/T/ipykernel_56395/589099134.py:11: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   preprocessing_df[columns_to_transform] = preprocessing_df[columns_to_transform].applymap(lambda x: 0 if pd.isnull(x) else 1)

# %%
preprocessing_df.columns
# Out:
# Index(['Carcode', 'Weight/Torque', 'Weight', 'Fuel', 'Weight/power',
#        'Max power regime.', 'Cylinder diameter', 'Fuel tank',
#        'Steering wheel adjustment height', 'Specific power',
#        'Multifunctional steering wheel',
#        'Driver s seat with height adjustment', 'Alloy wheels', 'Maximum power',
#        'Car size', 'Hot air', 'Rear window',
#        'Electric rearview mirror adjustment', 'Air conditioning',
#        'Frontal Airbags', 'Electric front window control', 'Folding rear seat',
#        'ABS brakes', 'Central locking of the doors',
#        'Perimeter anti theft alarm', 'Bluetooth connection', 'Acceleration',
#        'Length', 'Maximum torque', 'Width', 'Rev counter', 'Compression ratio',
#        'Assisted direction', 'Tuching', 'Guarantee', 'Drag coefficient',
#        'Height', 'Specific torque', 'Minimum height from the ground',
#        'Propulsion', 'Piston course', 'Car gearbox', 'Price R',
#        'Headrest for all occupants', 'Front gauge', 'Displacement',
#        'Cooling liquid thermometer', 'Turns diameter', 'Rear gauge',
#        'Length between the axis', 'Maximum speed', 'Devaluation',
#        'Road consumption', 'Max torque regime', 'Car payload', 'CNW Index',
#        'Reader score', 'Sidewall height', 'Provenance', 'On board computer',
#        'Light in the trunk', 'Settings', 'Unit displacement', 'Trunk',
#        'USB connection', 'Urban', 'Radio'],
#       dtype='object')

# %%
# Preprocess Acceleration (0100 km/h 3,8 s = 3.8)
preprocessing_df['Acceleration'] = preprocessing_df['Acceleration'].str.extract(r'(\d+\,\d+)')

# Replace ',' with '.' and convert to numeric
preprocessing_df['Acceleration'] = preprocessing_df['Acceleration'].str.replace(',', '.').astype(float)
# Rename Column
preprocessing_df = preprocessing_df.rename(columns={'Acceleration': 'Acceleration 0100 km/h in S'})

# %%
def process_truck_column(df):
    # Use regular expression to replace the unwanted text
    df['Trunk'] = df['Trunk'].str.replace(r'^.*lugares\s+', '', regex=True)
    return df

# %%
preprocessing_df=process_truck_column(preprocessing_df)

# %%
import pandas as pd
import re

def count_columns_with_numbers_and_units(df):
    """
    Counts the number of columns in a DataFrame that contain values with numbers followed by units.

    Parameters:
    - df: pd.DataFrame - The DataFrame to analyze.

    Returns:
    - int - The number of columns containing numbers and units.
    - list - The names of columns containing numbers and units.
    """
    columns_with_units = []
    pattern = re.compile(r'\d+(\.\d+)?\s+[a-zA-Z]+')  # Pattern for numbers followed by units

    for column in df.columns:
        if df[column].dtype == 'object':  # Only check object (string) columns
            if any(df[column].astype(str).apply(lambda x: bool(pattern.search(x)))):
                columns_with_units.append(column)

    return len(columns_with_units), columns_with_units

# Usage example (assuming preprocessing_df is your DataFrame):
# num_columns_with_units, columns_with_units = count_columns_with_numbers_and_units(preprocessing_df)
# print(f"Number of columns with numbers and units: {num_columns_with_units}")
# print(f"Columns with numbers and units: {columns_with_units}")

# %%
count_columns_with_numbers_and_units(df)
# Out:
# (69,
#  ['Power',
#   'Weight/Torque',
#   'Weight',
#   'Weight/power',
#   'Max power regime.',
#   'Cylinder diameter',
#   'Cylinders',
#   'Combined power',
#   'Engine code',
#   'Fuel tank',
#   'Specific power',
#   'Maximum powerG',
#   'Maximum power',
#   'Trailer with brake',
#   'Trailer without brakes',
#   'Maximum rotation',
#   'Acceleration',
#   'Length',
#   'Maximum torque',
#   'Width',
#   'Autonomy',
#   'Years',
#   'R reviews',
#   'Input angle',
#   'Torque',
#   'Guarantee',
#   'Height',
#   'Specific torque',
#   'Minimum height from the ground',
#   'Electrical autonomy',
#   'Maximum torqueG',
#   'Piston course',
#   'Rear tires',
#   'Urban autonomy',
#   'Urban consumptionG',
#   'Maximum ramp',
#   'Exit angle',
#   'Front gauge',
#   'Spare tire',
#   'Max side tilt',
#   'Displacement',
#   'Turns diameter',
#   'Electric consumption',
#   'Rear gauge',
#   'Frontal area A',
#   'Bucket',
#   'Length between the axis',
#   'Central angle',
#   'Maximum speed',
#   'Road autonomyG',
#   'Road consumption',
#   'Max torque regime',
#   'Car payload',
#   'Braking',
#   'Front tires',
#   'Water crossing',
#   'Road autonomy',
#   'Sidewall height',
#   'Battery capacity',
#   'Combined torque',
#   'Road consumptionG',
#   'Unit displacement',
#   'Trunk',
#   'Gear change code',
#   'Corrected frontal area',
#   'Urban',
#   'Platform',
#   'Urban autonomyG',
#   'Maximum speed electric mode'])

# %% [markdown]
# ## checking all the columns where single unit is present

# %%
from collections import defaultdict

def find_columns_with_single_unit_dict(df):
    # Regular expression to find units: numbers followed by space (optional) and letters
    pattern = re.compile(r'\d+(\.\d+)?\s*([a-zA-Z]+)')

    # Dictionary to hold unique units found across all columns
    units_found = defaultdict(set)

    # Iterate over each column in the DataFrame
    for column in df.columns:
        if df[column].dtype == 'object':  # Check only string-type columns
            for value in df[column].dropna().unique():
                matches = pattern.findall(value)
                for match in matches:
                    # Extract the unit part
                    if match[1]:  # match[1] contains the unit part from the regex group
                        units_found[column].add(match[1])

    # Create a dictionary for columns that have exactly one unique unit, mapping column names to their unit
    columns_with_single_unit_dict = {column: units.pop() for column, units in units_found.items() if len(units) == 1}

    return columns_with_single_unit_dict

# %%
one_unit_columns=find_columns_with_single_unit_dict(preprocessing_df)
one_unit_columns
# Out:
# {'Weight/Torque': 'kg',
#  'Weight': 'kg',
#  'Weight/power': 'kg',
#  'Max power regime.': 'rpm',
#  'Cylinder diameter': 'mm',
#  'Fuel tank': 'litros',
#  'Specific power': 'cv',
#  'Maximum power': 'cv',
#  'Length': 'mm',
#  'Maximum torque': 'kgfm',
#  'Width': 'mm',
#  'Height': 'mm',
#  'Specific torque': 'kgfm',
#  'Minimum height from the ground': 'mm',
#  'Piston course': 'mm',
#  'Front gauge': 'mm',
#  'Displacement': 'cm',
#  'Turns diameter': 'm',
#  'Rear gauge': 'mm',
#  'Length between the axis': 'mm',
#  'Maximum speed': 'km',
#  'Road consumption': 'km',
#  'Max torque regime': 'rpm',
#  'Car payload': 'kg',
#  'Sidewall height': 'mm',
#  'Unit displacement': 'cm',
#  'Trunk': 'litros',
#  'Urban': 'km'}

# %%
def remove_units_and_rename_columns(df, columns_units_dict):
    """
    Removes units from column values based on a provided dictionary mapping columns to their units,
    and renames the columns to include the unit.

    Parameters:
    - df: pd.DataFrame - The DataFrame to process.
    - columns_units_dict: dict - A dictionary where keys are column names and values are units.

    Returns:
    - pd.DataFrame - The DataFrame with units removed from values and columns renamed.
    """
    # Copy the DataFrame to avoid modifying the original
    df_processed = df.copy()

    # Regular expression to find and remove units: numbers followed by optional space and units
    pattern = re.compile(r'(\d+(\.\d+)?)\s*[a-zA-Z]+')

    for column, unit in columns_units_dict.items():
        # Check if the column exists to avoid KeyError
        if column in df_processed.columns:
            # Remove the unit from the column values, keeping only the numeric part
            df_processed[column] = df_processed[column].astype(str).apply(lambda x: pattern.sub(r'\1', x))
            # Convert the cleaned column to numeric type
            df_processed[column] = pd.to_numeric(df_processed[column], errors='coerce')
            # Rename the column to include the unit
            df_processed.rename(columns={column: f"{column} in {unit}"}, inplace=True)

    return df_processed

# %%
df_6=remove_units_and_rename_columns(preprocessing_df, one_unit_columns)
df_6.columns
# Out:
# Index(['Carcode', 'Weight/Torque in kg', 'Weight in kg', 'Fuel',
#        'Weight/power in kg', 'Max power regime. in rpm',
#        'Cylinder diameter in mm', 'Fuel tank in litros',
#        'Steering wheel adjustment height', 'Specific power in cv',
#        'Multifunctional steering wheel',
#        'Driver s seat with height adjustment', 'Alloy wheels',
#        'Maximum power in cv', 'Car size', 'Hot air', 'Rear window',
#        'Electric rearview mirror adjustment', 'Air conditioning',
#        'Frontal Airbags', 'Electric front window control', 'Folding rear seat',
#        'ABS brakes', 'Central locking of the doors',
#        'Perimeter anti theft alarm', 'Bluetooth connection', 'Acceleration',
#        'Length in mm', 'Maximum torque in kgfm', 'Width in mm', 'Rev counter',
#        'Compression ratio', 'Assisted direction', 'Tuching', 'Guarantee',
#        'Drag coefficient', 'Height in mm', 'Specific torque in kgfm',
#        'Minimum height from the ground in mm', 'Propulsion',
#        'Piston course in mm', 'Car gearbox', 'Price R',
#        'Headrest for all occupants', 'Front gauge in mm', 'Displacement in cm',
#        'Cooling liquid thermometer', 'Turns diameter in m', 'Rear gauge in mm',
#        'Length between the axis in mm', 'Maximum speed in km', 'Devaluation',
#        'Road consumption in km', 'Max torque regime in rpm',
#        'Car payload in kg', 'CNW Index', 'Reader score',
#        'Sidewall height in mm', 'Provenance', 'On board computer',
#        'Light in the trunk', 'Settings', 'Unit displacement in cm',
#        'Trunk in litros', 'USB connection', 'Urban in km', 'Radio'],
#       dtype='object')

# %%
import os

# Define the file path to the 'Downloads' directory
downloads_directory = os.path.expanduser('~/Downloads')

# Specify the full file path for saving the CSV file
csv_file_path = os.path.join(downloads_directory, 'df_6.csv')

# Save the DataFrame to the CSV file
df_6.to_csv(csv_file_path, index=False)

# %% [markdown]
# ## column with 2 units

# %%
def find_unique_units_set(df):
    # Regular expression to find units: numbers followed by space (optional) and letters
    pattern = re.compile(r'\d+(\.\d+)?\s*([a-zA-Z]+)')

    # Dictionary to hold unique units found across all columns
    units_found = defaultdict(set)

    # Iterate over each column in the DataFrame
    for column in df.columns:
        if df[column].dtype == 'object':  # Check only string-type columns
            for value in df[column].dropna().unique():
                matches = pattern.findall(value)
                for match in matches:
                    # Extract the unit part
                    if match[1]:  # match[1] contains the unit part from the regex group
                        units_found[column].add(match[1])

    # Extract all unique single units into a set
    unique_units_set = {units.pop() for units in units_found.values() if len(units) == 1}

    return unique_units_set

# %%
from collections import defaultdict


unit_dict = defaultdict(set,
            {'Acceleration': {'km', 's'},
             'Length': {'mm'},
             'Maximum torque': {'kgfm'},
             'Width': {'mm'},
             'Weight/Torque': {'kg'},
             'Guarantee': {'year', 'years'},
             'Height': {'mm'},
             'Specific torque': {'kgfm'},
             'Minimum height from the ground': {'mm'},
             'Piston course': {'mm'},
             'Weight': {'kg'},
             'Front gauge': {'mm'},
             'Weight/power': {'kg'},
             'Displacement': {'cm'},
             'Max power regime.': {'rpm'},
             'Turns diameter': {'m'},
             'Cylinder diameter': {'mm'},
             'Rear gauge': {'mm'},
             'Length between the axis': {'mm'},
             'Maximum speed': {'km'},
             'Fuel tank': {'litros'},
             'Road consumption': {'km'},
             'Max torque regime': {'rpm'},
             'Car payload': {'kg'},
             'Specific power': {'cv'},
             'Sidewall height': {'mm'},
             'Maximum power': {'cv'},
             'Unit displacement': {'cm'},
             'Trunk': {'litros', 'lugares'},
             'Urban': {'km'}})

two_value_dicts = {key: value_set for key, value_set in unit_dict.items() if len(value_set) == 2}

print(two_value_dicts)
# Out:
# {'Acceleration': {'km', 's'}, 'Guarantee': {'years', 'year'}, 'Trunk': {'lugares', 'litros'}}

# %% [markdown]
# ## Processing Guarantee column

# %%
def process_guarantee_column(df):
    new_df = df.copy()

    # Remove 'year' or 'years' from 'Guarantee' column values
    new_df['Guarantee'] = new_df['Guarantee'].str.replace(r'\s*years?\s*', '', regex=True)

    # Rename the column to 'Guarantee in years'
    new_df = new_df.rename(columns={'Guarantee': 'Guarantee in years'})

    return new_df

# %%
guarante=process_guarantee_column(preprocessing_df)
guarante['Guarantee in years']
# Out:
# 0        1
# 1        1
# 2        1
# 4        1
# 5        1
#         ..
# 23881    5
# 23882    5
# 23890    5
# 23902    1
# 23903    1
# Name: Guarantee in years, Length: 20708, dtype: object

# %% [markdown]
# ## processing Truck column

# %%
def process_truck_column(df):
    # Use regular expression to replace the unwanted text
    df['Truck'] = df['Truck'].str.replace(r'^.*lugares\s+', '', regex=True)
    return df

# %%
truck=process_truck_column(preprocessing_df)

# %%
column_names_single_unit=[]
for i in one_unit_columns:
    column_names_single_unit.append(i)

column_names_single_unit
# Out:
# ['Length',
#  'Maximum torque',
#  'Width',
#  'Weight/Torque',
#  'Height',
#  'Specific torque',
#  'Minimum height from the ground',
#  'Piston course',
#  'Weight',
#  'Front gauge',
#  'Weight/power',
#  'Displacement',
#  'Max power regime.',
#  'Turns diameter',
#  'Cylinder diameter',
#  'Rear gauge',
#  'Length between the axis',
#  'Maximum speed',
#  'Fuel tank',
#  'Road consumption',
#  'Max torque regime',
#  'Car payload',
#  'Specific power',
#  'Sidewall height',
#  'Maximum power',
#  'Unit displacement',
#  'Urban']

# %%
def find_unique_units_set(df):
    # Regular expression to find units: numbers followed by space (optional) and letters
    pattern = re.compile(r'\d+(\.\d+)?\s*([a-zA-Z]+)')

    # Dictionary to hold unique units found across all columns
    units_found = defaultdict(set)

    # Iterate over each column in the DataFrame
    for column in df.columns:
        if df[column].dtype == 'object':  # Check only string-type columns
            for value in df[column].dropna().unique():
                matches = pattern.findall(value)
                for match in matches:
                    # Extract the unit part
                    if match[1]:  # match[1] contains the unit part from the regex group
                        units_found[column].add(match[1])

    # Extract all unique single units into a set
    unique_units_set = {units.pop() for units in units_found.values() if len(units) == 1}

    return unique_units_set

# %%
# set of units from single unit columns
set_of_units=find_unique_units_set(preprocessing_df)
set_of_units
# Out:
# {'cm', 'cv', 'kg', 'kgfm', 'km', 'litros', 'm', 'mm', 'rpm'}

# %%
len(column_names_single_unit)
# Out:
# 27

# %%
dict=find_all_units(preprocessing_df)
dict
# Out:
# defaultdict(set,
#             {'Acceleration': {'km', 's'},
#              'Length': {'mm'},
#              'Maximum torque': {'kgfm'},
#              'Width': {'mm'},
#              'Weight/Torque': {'kg'},
#              'Guarantee': {'year', 'years'},
#              'Height': {'mm'},
#              'Specific torque': {'kgfm'},
#              'Minimum height from the ground': {'mm'},
#              'Piston course': {'mm'},
#              'Weight': {'kg'},
#              'Front gauge': {'mm'},
#              'Weight/power': {'kg'},
#              'Displacement': {'cm'},
#              'Max power regime.': {'rpm'},
#              'Turns diameter': {'m'},
#              'Cylinder diameter': {'mm'},
#              'Rear gauge': {'mm'},
#              'Length between the axis': {'mm'},
#              'Maximum speed': {'km'},
#              'Fuel tank': {'litros'},
#              'Road consumption': {'km'},
#              'Max torque regime': {'rpm'},
#              'Car payload': {'kg'},
#              'Specific power': {'cv'},
#              'Sidewall height': {'mm'},
#              'Maximum power': {'cv'},
#              'Unit displacement': {'cm'},
#              'Trunk': {'litros', 'lugares'},
#              'Urban': {'km'}})

# %%
from collections import defaultdict

unit_dict = defaultdict(set,
            {'Acceleration': {'km', 's'},
             'Length': {'mm'},
             'Maximum torque': {'kgfm'},
             'Width': {'mm'},
             'Weight/Torque': {'kg'},
             'Guarantee': {'year', 'years'},
             'Height': {'mm'},
             'Specific torque': {'kgfm'},
             'Minimum height from the ground': {'mm'},
             'Piston course': {'mm'},
             'Weight': {'kg'},
             'Front gauge': {'mm'},
             'Weight/power': {'kg'},
             'Displacement': {'cm'},
             'Max power regime.': {'rpm'},
             'Turns diameter': {'m'},
             'Cylinder diameter': {'mm'},
             'Rear gauge': {'mm'},
             'Length between the axis': {'mm'},
             'Maximum speed': {'km'},
             'Fuel tank': {'litros'},
             'Road consumption': {'km'},
             'Max torque regime': {'rpm'},
             'Car payload': {'kg'},
             'Specific power': {'cv'},
             'Sidewall height': {'mm'},
             'Maximum power': {'cv'},
             'Unit displacement': {'cm'},
             'Trunk': {'litros', 'lugares'},
             'Urban': {'km'}})

two_value_dicts = {key: value_set for key, value_set in unit_dict.items() if len(value_set) == 2}

print(two_value_dicts)
# Out:
# {'Acceleration': {'km', 's'}, 'Guarantee': {'year', 'years'}, 'Trunk': {'litros', 'lugares'}}

# %%
# Create a new dictionary with key-value pairs where the value contains more than 2 elements
filtered_dict = {key: value for key, value in find_all_units[1].items() if len(value) > 2}

print(filtered_dict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[86], line 2
#       1 # Create a new dictionary with key-value pairs where the value contains more than 2 elements
# ----> 2 filtered_dict = {key: value for key, value in find_all_units[1].items() if len(value) > 2}
#       4 print(filtered_dict)
#
# TypeError: 'function' object is not subscriptable

# %% [markdown]
# ## column has rpm in the unit

# %%
def count_columns_with_rpm(df):

    columns_with_rpm = []

    for column in df.columns:
        if df[column].dtype == 'object':  # Only check object (string) columns
            # Check if any value in the column contains 'kg'
            if df[column].astype(str).str.contains('rpm').any():
                columns_with_rpm.append(column)

    return columns_with_rpm

# %%
column_list_rpm=count_columns_with_rpm(preprocessing_df)

# %%
def process_and_rename_columns_in_rpm(df, columns_list):

    # Copy the DataFrame to avoid modifying the original
    df_processed = df.copy()

    for column_name in columns_list:
        # Remove ' rpm' and convert to numeric, handling errors by coercing them to NaN
        df_processed[column_name] = pd.to_numeric(df_processed[column_name].str.replace(' rpm', ''), errors='coerce')

        # Rename the column
        new_name = f"{column_name} in rpm"
        df_processed = df_processed.rename(columns={column_name: new_name})

    return df_processed

# %%
df3=process_and_rename_columns_in_rpm(preprocessing_df, column_list_rpm)
df3.columns
# Out:
# Index(['Hot air', 'Acceleration', 'Length', 'Maximum torque', 'Width',
#        'Rev counter', 'Compression ratio', 'Assisted direction', 'CNW Ranking',
#        'ABS brakes', 'Rear window', 'Tuching', 'Weight/Torque', 'Guarantee',
#        'Drag coefficient', 'Central locking of the doors', 'Height',
#        'Valves per cylinder', 'Specific torque',
#        'Minimum height from the ground', 'Propulsion', 'Piston course',
#        'Car gearbox', 'Weight', 'Price R', 'Headrest for all occupants',
#        'Front gauge', 'Fuel', 'Electric rearview mirror adjustment',
#        'Weight/power', 'Displacement', 'Cooling liquid thermometer',
#        'Max power regime. in rpm', 'Turns diameter', 'Cylinder diameter',
#        'Air conditioning', 'Rear gauge', 'Length between the axis',
#        'Bluetooth connection', 'Frontal Airbags', 'Maximum speed', 'Fuel tank',
#        'Devaluation', 'Road consumption', 'Max torque regime in rpm',
#        'Car payload', 'Steering wheel adjustment height',
#        'Electric front window control', 'Specific power', 'CNW Index',
#        'Reader score', 'Multifunctional steering wheel',
#        'Driver s seat with height adjustment', 'Sidewall height', 'Provenance',
#        'On board computer', 'Light in the trunk', 'Alloy wheels', 'Doors',
#        'Maximum power', 'Settings', 'Car size', 'Unit displacement', 'Trunk',
#        'USB connection', 'Gear speed transmissions', 'Urban', 'Year', 'Radio',
#        'Folding rear seat', 'Perimeter anti theft alarm'],
#       dtype='object')

# %% [markdown]
# ## column has kgfm in the units

# %%
def count_columns_with_kgfm(df):

    columns_with_kgfm= []

    for column in df.columns:
        if df[column].dtype == 'object':  # Only check object (string) columns
            # Check if any value in the column contains 'kg'
            if df[column].astype(str).str.contains('rpm').any():
                columns_with_kgfm.append(column)

    return columns_with_kgfm

# %%
column_list_kgfm=count_columns_with_kgfm(preprocessing_df)
column_list_kgfm
# Out:
# ['Max power regime.', 'Max torque regime']

# %%
def process_and_rename_columns_in_kgfm(df, columns_list):

    # Copy the DataFrame to avoid modifying the original
    df_processed = df.copy()

    for column_name in columns_list:
        # Remove ' rpm' and convert to numeric, handling errors by coercing them to NaN
        df_processed[column_name] = pd.to_numeric(df_processed[column_name].str.replace(' rpm', ''), errors='coerce')

        # Rename the column
        new_name = f"{column_name} in kgfm"
        df_processed = df_processed.rename(columns={column_name: new_name})

    return df_processed

# %%
df4=process_and_rename_columns_in_kgfm(preprocessing_df, column_list_kgfm)
df4.columns
# Out:
# Index(['Hot air', 'Acceleration', 'Length', 'Maximum torque', 'Width',
#        'Rev counter', 'Compression ratio', 'Assisted direction', 'CNW Ranking',
#        'ABS brakes', 'Rear window', 'Tuching', 'Weight/Torque', 'Guarantee',
#        'Drag coefficient', 'Central locking of the doors', 'Height',
#        'Valves per cylinder', 'Specific torque',
#        'Minimum height from the ground', 'Propulsion', 'Piston course',
#        'Car gearbox', 'Weight', 'Price R', 'Headrest for all occupants',
#        'Front gauge', 'Fuel', 'Electric rearview mirror adjustment',
#        'Weight/power', 'Displacement', 'Cooling liquid thermometer',
#        'Max power regime. in kgfm', 'Turns diameter', 'Cylinder diameter',
#        'Air conditioning', 'Rear gauge', 'Length between the axis',
#        'Bluetooth connection', 'Frontal Airbags', 'Maximum speed', 'Fuel tank',
#        'Devaluation', 'Road consumption', 'Max torque regime in kgfm',
#        'Car payload', 'Steering wheel adjustment height',
#        'Electric front window control', 'Specific power', 'CNW Index',
#        'Reader score', 'Multifunctional steering wheel',
#        'Driver s seat with height adjustment', 'Sidewall height', 'Provenance',
#        'On board computer', 'Light in the trunk', 'Alloy wheels', 'Doors',
#        'Maximum power', 'Settings', 'Car size', 'Unit displacement', 'Trunk',
#        'USB connection', 'Gear speed transmissions', 'Urban', 'Year', 'Radio',
#        'Folding rear seat', 'Perimeter anti theft alarm'],
#       dtype='object')

# %% [markdown]
# ## column has cm in units

# %%
def count_columns_with_cm(df):

    columns_with_cm= []

    for column in df.columns:
        if df[column].dtype == 'object':  # Only check object (string) columns
            # Check if any value in the column contains 'kg'
            if df[column].astype(str).str.contains('cm').any():
                columns_with_cm.append(column)

    return columns_with_cm

# %%
column_list_cm=count_columns_with_cm(preprocessing_df)
column_list_cm
# Out:
# ['Displacement', 'Unit displacement']

# %%
def process_and_rename_columns_in_cm(df, columns_list):

    # Copy the DataFrame to avoid modifying the original
    df_processed = df.copy()

    for column_name in columns_list:
        # Remove ' rpm' and convert to numeric, handling errors by coercing them to NaN
        df_processed[column_name] = pd.to_numeric(df_processed[column_name].str.replace(' cm', ''), errors='coerce')

        # Rename the column
        new_name = f"{column_name} in cm"
        df_processed = df_processed.rename(columns={column_name: new_name})

    return df_processed

# %%
df5=process_and_rename_columns_in_cm(preprocessing_df, column_list_cm)
df5.columns
# Out:
# Index(['Hot air', 'Acceleration', 'Length', 'Maximum torque', 'Width',
#        'Rev counter', 'Compression ratio', 'Assisted direction', 'CNW Ranking',
#        'ABS brakes', 'Rear window', 'Tuching', 'Weight/Torque', 'Guarantee',
#        'Drag coefficient', 'Central locking of the doors', 'Height',
#        'Valves per cylinder', 'Specific torque',
#        'Minimum height from the ground', 'Propulsion', 'Piston course',
#        'Car gearbox', 'Weight', 'Price R', 'Headrest for all occupants',
#        'Front gauge', 'Fuel', 'Electric rearview mirror adjustment',
#        'Weight/power', 'Displacement in cm', 'Cooling liquid thermometer',
#        'Max power regime.', 'Turns diameter', 'Cylinder diameter',
#        'Air conditioning', 'Rear gauge', 'Length between the axis',
#        'Bluetooth connection', 'Frontal Airbags', 'Maximum speed', 'Fuel tank',
#        'Devaluation', 'Road consumption', 'Max torque regime', 'Car payload',
#        'Steering wheel adjustment height', 'Electric front window control',
#        'Specific power', 'CNW Index', 'Reader score',
#        'Multifunctional steering wheel',
#        'Driver s seat with height adjustment', 'Sidewall height', 'Provenance',
#        'On board computer', 'Light in the trunk', 'Alloy wheels', 'Doors',
#        'Maximum power', 'Settings', 'Car size', 'Unit displacement in cm',
#        'Trunk', 'USB connection', 'Gear speed transmissions', 'Urban', 'Year',
#        'Radio', 'Folding rear seat', 'Perimeter anti theft alarm'],
#       dtype='object')
